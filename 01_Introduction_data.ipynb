# %% [markdown]
# # Show the disaggregator overview

# %%
from IPython.display import Image
pic = Image(filename=('./img/overview.png'))
pic

# %% [markdown]
# # Introduction

# %% [markdown]
# ## Module `config.py`

# %% [markdown]
# The `config.py`-module is resonsible for all configuration needs of the entire program. This encompasses tasks such as, but not limited to:
# - making I/O paths available,
# - processing the contents of the `config.yaml`-file,
# - establishing a connection to the demandregio database through a RESTful-API and
# - providing data assignments based on dictionaries.

# %%
from disaggregator import config

# %% [markdown]
# Load config from the ``config.yaml``-file and get a value from a key, e.g.:

# %%
cfg = config.get_config()
cfg['database_host']
# Out:
# 'http://opendata.ffe.de:4000/'

# %% [markdown]
# A typical example for assignments are those between the NUTS-3-code and its real-world name of the 401 regions in Germany. These can be accessed through:

# %%
dict_nuts3_name = config.region_id_to_nuts3(nuts3_to_name=True)
dict_nuts3_name
# Out:
# {'DE915': 'Göttingen',
#  'DE919': 'Osterode am Harz',
#  'DEF01': 'Flensburg, Kreisfreie Stadt',
#  'DEF02': 'Kiel, Kreisfreie Stadt',
#  'DEF03': 'Lübeck, Kreisfreie Stadt',
#  'DEF04': 'Neumünster, Kreisfreie Stadt',
#  'DEF05': 'Dithmarschen',
#  'DEF06': 'Herzogtum Lauenburg',
#  'DE278': 'Günzburg',
#  'DEF07': 'Nordfriesland',
#  'DEF08': 'Ostholstein',
#  'DEF09': 'Pinneberg',
#  'DEF0A': 'Plön',
#  'DEF0B': 'Rendsburg-Eckernförde',
#  'DEF0C': 'Schleswig-Flensburg',
#  'DEF0D': 'Segeberg',
#  'DEF0E': 'Steinburg',
#  'DEF0F': 'Stormarn',
#  'DE600': 'Hamburg',
#  'DE911': 'Braunschweig, Kreisfreie Stadt',
#  'DE912': 'Salzgitter, Kreisfreie Stadt',
#  'DE913': 'Wolfsburg, Kreisfreie Stadt',
#  'DE914': 'Gifhorn',
#  'DE916': 'Goslar',
#  'DE917': 'Helmstedt',
#  'DE918': 'Northeim',
#  'DE91A': 'Peine',
#  'DE91B': 'Wolfenbüttel',
#  'DE91C': 'Göttingen',
#  'DE929': 'Region Hannover',
#  'DE922': 'Diepholz',
#  'DE923': 'Hameln-Pyrmont',
#  'DE925': 'Hildesheim',
#  'DE926': 'Holzminden',
#  'DE927': 'Nienburg (Weser)',
#  'DE928': 'Schaumburg',
#  'DE931': 'Celle',
#  'DE932': 'Cuxhaven',
#  'DE933': 'Harburg',
#  'DE934': 'Lüchow-Dannenberg',
#  'DE935': 'Lüneburg, Landkreis',
#  'DE936': 'Osterholz',
#  'DE937': 'Rotenburg (Wümme)',
#  'DE938': 'Heidekreis',
#  'DE939': 'Stade',
#  'DE93A': 'Uelzen',
#  'DE93B': 'Verden',
#  'DE941': 'Delmenhorst, Kreisfreie Stadt',
#  'DE942': 'Emden, Kreisfreie Stadt',
#  'DE943': 'Oldenburg (Oldenburg), Kreisfreie Stadt',
#  'DE944': 'Osnabrück, Kreisfreie Stadt',
#  'DE945': 'Wilhelmshaven, Kreisfreie Stadt',
#  'DE946': 'Ammerland',
#  'DE947': 'Aurich',
#  'DE948': 'Cloppenburg',
#  'DE949': 'Emsland',
#  'DE94A': 'Friesland (DE)',
#  'DE94B': 'Grafschaft Bentheim',
#  'DE94C': 'Leer',
#  'DE94D': 'Oldenburg, Landkreis',
#  'DE94E': 'Osnabrück, Landkreis',
#  'DE94F': 'Vechta',
#  'DE94G': 'Wesermarsch',
#  'DE94H': 'Wittmund',
#  'DE501': 'Bremen, Kreisfreie Stadt',
#  'DE502': 'Bremerhaven, Kreisfreie Stadt',
#  'DEA11': 'Düsseldorf, Kreisfreie Stadt',
#  'DEA12': 'Duisburg, Kreisfreie Stadt',
#  'DEA13': 'Essen, Kreisfreie Stadt',
#  'DEA14': 'Krefeld, Kreisfreie Stadt',
#  'DEA15': 'Mönchengladbach, Kreisfreie Stadt',
#  'DEA16': 'Mülheim an der Ruhr,Kreisfreie Stadt',
#  'DEA17': 'Oberhausen, Kreisfreie Stadt',
#  'DEA18': 'Remscheid, Kreisfreie Stadt',
#  'DEA19': 'Solingen, Kreisfreie Stadt',
#  'DEA1A': 'Wuppertal, Kreisfreie Stadt',
#  'DEA1B': 'Kleve',
#  'DEA1C': 'Mettmann',
#  'DEA1D': 'Rhein-Kreis Neuss',
#  'DEA1E': 'Viersen',
#  'DEA1F': 'Wesel',
#  'DEA22': 'Bonn, Kreisfreie Stadt',
#  'DEA23': 'Köln, Kreisfreie Stadt',
#  'DEA24': 'Leverkusen, Kreisfreie Stadt',
#  'DEA2D': 'Städteregion Aachen',
#  'DEA26': 'Düren',
#  'DEA27': 'Rhein-Erft-Kreis',
#  'DEA28': 'Euskirchen',
#  'DEA29': 'Heinsberg',
#  'DEA2A': 'Oberbergischer Kreis',
#  'DEA2B': 'Rheinisch-Bergischer Kreis',
#  'DEA2C': 'Rhein-Sieg-Kreis',
#  'DEA31': 'Bottrop, Kreisfreie Stadt',
#  'DEA32': 'Gelsenkirchen, Kreisfreie Stadt',
#  'DEA33': 'Münster, Kreisfreie Stadt',
#  'DEA34': 'Borken',
#  'DEA35': 'Coesfeld',
#  'DEA36': 'Recklinghausen',
#  'DEA37': 'Steinfurt',
#  'DEA38': 'Warendorf',
#  'DEA41': 'Bielefeld, Kreisfreie Stadt',
#  'DEA42': 'Gütersloh',
#  'DEA43': 'Herford',
#  'DEA44': 'Höxter',
#  'DEA45': 'Lippe',
#  'DEA46': 'Minden-Lübbecke',
#  'DEA47': 'Paderborn',
#  'DEA51': 'Bochum, Kreisfreie Stadt',
#  'DEA52': 'Dortmund, Kreisfreie Stadt',
#  'DEA53': 'Hagen, Kreisfreie Stadt',
#  'DEA54': 'Hamm, Kreisfreie Stadt',
#  'DEA55': 'Herne, Kreisfreie Stadt',
#  'DEA56': 'Ennepe-Ruhr-Kreis',
#  'DEA57': 'Hochsauerlandkreis',
#  'DEA58': 'Märkischer Kreis',
#  'DEA59': 'Olpe',
#  'DEA5A': 'Siegen-Wittgenstein',
#  'DEA5B': 'Soest',
#  'DEA5C': 'Unna',
#  'DE711': 'Darmstadt, Kreisfreie Stadt',
#  'DE712': 'Frankfurt am Main, Kreisfreie Stadt',
#  'DE713': 'Offenbach am Main, Kreisfreie Stadt',
#  'DE714': 'Wiesbaden, Kreisfreie Stadt',
#  'DE715': 'Bergstraße',
#  'DE716': 'Darmstadt-Dieburg',
#  'DE717': 'Groß-Gerau',
#  'DE718': 'Hochtaunuskreis',
#  'DE719': 'Main-Kinzig-Kreis',
#  'DE71A': 'Main-Taunus-Kreis',
#  'DE71B': 'Odenwaldkreis',
#  'DE71C': 'Offenbach, Landkreis',
#  'DE71D': 'Rheingau-Taunus-Kreis',
#  'DE71E': 'Wetteraukreis',
#  'DE721': 'Gießen, Landkreis',
#  'DE722': 'Lahn-Dill-Kreis',
#  'DE723': 'Limburg-Weilburg',
#  'DE724': 'Marburg-Biedenkopf',
#  'DE725': 'Vogelsbergkreis',
#  'DE731': 'Kassel, Kreisfreie Stadt',
#  'DE732': 'Fulda',
#  'DE733': 'Hersfeld-Rotenburg',
#  'DE734': 'Kassel, Landkreis',
#  'DE735': 'Schwalm-Eder-Kreis',
#  'DE736': 'Waldeck-Frankenberg',
#  'DE737': 'Werra-Meißner-Kreis',
#  'DEB11': 'Koblenz, Kreisfreie Stadt',
#  'DEB12': 'Ahrweiler',
#  'DEB13': 'Altenkirchen (Westerwald)',
#  'DEB14': 'Bad Kreuznach',
#  'DEB15': 'Birkenfeld',
#  'DEB16': 'Cochem-Zell',
#  'DEB17': 'Mayen-Koblenz',
#  'DEB18': 'Neuwied',
#  'DEB19': 'Rhein-Hunsrück-Kreis',
#  'DEB1A': 'Rhein-Lahn-Kreis',
#  'DEB1B': 'Westerwaldkreis',
#  'DEB21': 'Trier, Kreisfreie Stadt',
#  'DEB22': 'Bernkastel-Wittlich',
#  'DEB23': 'Eifelkreis Bitburg-Prüm',
#  'DEB24': 'Vulkaneifel',
#  'DEB25': 'Trier-Saarburg',
#  'DEB31': 'Frankenthal (Pfalz), Kreisfreie Stadt',
#  'DEB32': 'Kaiserslautern, Kreisfreie Stadt',
#  'DEB33': 'Landau in der Pfalz, Kreisfreie Stadt',
#  'DEB34': 'Ludwigshafen am Rhein, Kreisfreie Stadt',
#  'DEB35': 'Mainz, Kreisfreie Stadt',
#  'DEB36': 'Neustadt an der Weinstraße, Kreisfreie Stadt',
#  'DEB37': 'Pirmasens, Kreisfreie Stadt',
#  'DEB38': 'Speyer, Kreisfreie Stadt',
#  'DEB39': 'Worms, Kreisfreie Stadt',
#  'DEB3A': 'Zweibrücken, Kreisfreie Stadt',
#  'DEB3B': 'Alzey-Worms',
#  'DEB3C': 'Bad Dürkheim',
#  'DEB3D': 'Donnersbergkreis',
#  'DEB3E': 'Germersheim',
#  'DEB3F': 'Kaiserslautern, Landkreis',
#  'DEB3G': 'Kusel',
#  'DEB3H': 'Südliche Weinstraße',
#  'DEB3I': 'Rhein-Pfalz-Kreis',
#  'DEB3J': 'Mainz-Bingen',
#  'DEB3K': 'Südwestpfalz',
#  'DE111': 'Stuttgart, Stadtkreis',
#  'DE112': 'Böblingen',
#  'DE113': 'Esslingen',
#  'DE114': 'Göppingen',
#  'DE115': 'Ludwigsburg',
#  'DE116': 'Rems-Murr-Kreis',
#  'DE117': 'Heilbronn, Stadtkreis',
#  'DE118': 'Heilbronn, Landkreis',
#  'DE119': 'Hohenlohekreis',
#  'DE11A': 'Schwäbisch Hall',
#  'DE11B': 'Main-Tauber-Kreis',
#  'DE11C': 'Heidenheim',
#  'DE11D': 'Ostalbkreis',
#  'DE121': 'Baden-Baden, Stadtkreis',
#  'DE122': 'Karlsruhe, Stadtkreis',
#  'DE123': 'Karlsruhe, Landkreis',
#  'DE124': 'Rastatt',
#  'DE125': 'Heidelberg, Stadtkreis',
#  'DE126': 'Mannheim, Stadtkreis',
#  'DE127': 'Neckar-Odenwald-Kreis',
#  'DE128': 'Rhein-Neckar-Kreis',
#  'DE129': 'Pforzheim, Stadtkreis',
#  'DE12A': 'Calw',
#  'DE12B': 'Enzkreis',
#  'DE12C': 'Freudenstadt',
#  'DE131': 'Freiburg im Breisgau, Stadtkreis',
#  'DE132': 'Breisgau-Hochschwarzwald',
#  'DE133': 'Emmendingen',
#  'DE134': 'Ortenaukreis',
#  'DE135': 'Rottweil',
#  'DE136': 'Schwarzwald-Baar-Kreis',
#  'DE137': 'Tuttlingen',
#  'DE138': 'Konstanz',
#  'DE139': 'Lörrach',
#  'DE13A': 'Waldshut',
#  'DE141': 'Reutlingen',
#  'DE142': 'Tübingen, Landkreis',
#  'DE143': 'Zollernalbkreis',
#  'DE144': 'Ulm, Stadtkreis',
#  'DE145': 'Alb-Donau-Kreis',
#  'DE146': 'Biberach',
#  'DE147': 'Bodenseekreis',
#  'DE148': 'Ravensburg',
#  'DE149': 'Sigmaringen',
#  'DE211': 'Ingolstadt, Kreisfreie Stadt',
#  'DE212': 'München, Kreisfreie Stadt',
#  'DE213': 'Rosenheim, Kreisfreie Stadt',
#  'DE214': 'Altötting',
#  'DE215': 'Berchtesgadener Land',
#  'DE216': 'Bad Tölz-Wolfratshausen',
#  'DE217': 'Dachau',
#  'DE218': 'Ebersberg',
#  'DE219': 'Eichstätt',
#  'DE21A': 'Erding',
#  'DE21B': 'Freising',
#  'DE21C': 'Fürstenfeldbruck',
#  'DE21D': 'Garmisch-Partenkirchen',
#  'DE21E': 'Landsberg am Lech',
#  'DE21F': 'Miesbach',
#  'DE21G': 'Mühldorf a. Inn',
#  'DE21H': 'München, Landkreis',
#  'DE21I': 'Neuburg-Schrobenhausen',
#  'DE21J': 'Pfaffenhofen a. d. Ilm',
#  'DE21K': 'Rosenheim, Landkreis',
#  'DE21L': 'Starnberg',
#  'DE21M': 'Traunstein',
#  'DE21N': 'Weilheim-Schongau',
#  'DE221': 'Landshut, Kreisfreie Stadt',
#  'DE222': 'Passau, Kreisfreie Stadt',
#  'DE223': 'Straubing, Kreisfreie Stadt',
#  'DE224': 'Deggendorf',
#  'DE225': 'Freyung-Grafenau',
#  'DE226': 'Kelheim',
#  'DE227': 'Landshut, Landkreis',
#  'DE228': 'Passau, Landkreis',
#  'DE229': 'Regen',
#  'DE22A': 'Rottal-Inn',
#  'DE22B': 'Straubing-Bogen',
#  'DE22C': 'Dingolfing-Landau',
#  'DE231': 'Amberg, Kreisfreie Stadt',
#  'DE232': 'Regensburg, Kreisfreie Stadt',
#  'DE233': 'Weiden i. d. Opf, Kreisfreie Stadt',
#  'DE234': 'Amberg-Sulzbach',
#  'DE235': 'Cham',
#  'DE236': 'Neumarkt i. d. OPf.',
#  'DE237': 'Neustadt a. d. Waldnaab',
#  'DE238': 'Regensburg, Landkreis',
#  'DE239': 'Schwandorf',
#  'DE23A': 'Tirschenreuth',
#  'DE241': 'Bamberg, Kreisfreie Stadt',
#  'DE242': 'Bayreuth, Kreisfreie Stadt',
#  'DE243': 'Coburg, Kreisfreie Stadt',
#  'DE244': 'Hof, Kreisfreie Stadt',
#  'DE245': 'Bamberg, Landkreis',
#  'DE246': 'Bayreuth, Landkreis',
#  'DE247': 'Coburg, Landkreis',
#  'DE248': 'Forchheim',
#  'DE249': 'Hof, Landkreis',
#  'DE24A': 'Kronach',
#  'DE24B': 'Kulmbach',
#  'DE24C': 'Lichtenfels',
#  'DE24D': 'Wunsiedel i. Fichtelgebirge',
#  'DE251': 'Ansbach, Kreisfreie Stadt',
#  'DE252': 'Erlangen, Kreisfreie Stadt',
#  'DE253': 'Fürth, Kreisfreie Stadt',
#  'DE254': 'Nürnberg, Kreisfreie Stadt',
#  'DE255': 'Schwabach, Kreisfreie Stadt',
#  'DE256': 'Ansbach, Landkreis',
#  'DE257': 'Erlangen-Höchstadt',
#  'DE258': 'Fürth, Landkreis',
#  'DE259': 'Nürnberger Land',
#  'DE25A': 'Neustadt a. d. Aisch-Bad Windsheim',
#  'DE25B': 'Roth',
#  'DE25C': 'Weißenburg-Gunzenhausen',
#  'DE261': 'Aschaffenburg, Kreisfreie Stadt',
#  'DE262': 'Schweinfurt, Kreisfreie Stadt',
#  'DE263': 'Würzburg, Kreisfreie Stadt',
#  'DE264': 'Aschaffenburg, Landkreis',
#  'DE265': 'Bad Kissingen',
#  'DE266': 'Rhön-Grabfeld',
#  'DE267': 'Haßberge',
#  'DE268': 'Kitzingen',
#  'DE269': 'Miltenberg',
#  'DE26A': 'Main-Spessart',
#  'DE26B': 'Schweinfurt, Landkreis',
#  'DE26C': 'Würzburg, Landkreis',
#  'DE271': 'Augsburg, Kreisfreie Stadt',
#  'DE272': 'Kaufbeuren, Kreisfreie Stadt',
#  'DE273': 'Kempten (Allgäu), Kreisfreie Stadt',
#  'DE274': 'Memmingen, Kreisfreie Stadt',
#  'DE275': 'Aichach-Friedberg',
#  'DE276': 'Augsburg, Landkreis',
#  'DE277': 'Dillingen a.d. Donau',
#  'DE279': 'Neu-Ulm',
#  'DE27A': 'Lindau (Bodensee)',
#  'DE27B': 'Ostallgäu',
#  'DE27C': 'Unterallgäu',
#  'DE27D': 'Donau-Ries',
#  'DE27E': 'Oberallgäu',
#  'DEC01': 'Regionalverband Saarbrücken',
#  'DEC02': 'Merzig-Wadern',
#  'DEC03': 'Neunkirchen',
#  'DEC04': 'Saarlouis',
#  'DEC05': 'Saarpfalz-Kreis',
#  'DEC06': 'St. Wendel',
#  'DE300': 'Berlin',
#  'DE401': 'Brandenburg an der Havel, Kreisfreie Stadt',
#  'DE402': 'Cottbus, Kreisfreie Stadt',
#  'DE403': 'Frankfurt (Oder), Kreisfreie Stadt',
#  'DE404': 'Potsdam, Kreisfreie Stadt',
#  'DE405': 'Barnim',
#  'DE406': 'Dahme-Spreewald',
#  'DE407': 'Elbe-Elster',
#  'DE408': 'Havelland',
#  'DE409': 'Märkisch-Oderland',
#  'DE40A': 'Oberhavel',
#  'DE40B': 'Oberspreewald-Lausitz',
#  'DE40C': 'Oder-Spree',
#  'DE40D': 'Ostprignitz-Ruppin',
#  'DE40E': 'Potsdam-Mittelmark',
#  'DE40F': 'Prignitz',
#  'DE40G': 'Spree-Neiße',
#  'DE40H': 'Teltow-Fläming',
#  'DE40I': 'Uckermark',
#  'DE803': 'Rostock, Kreisfreie Stadt',
#  'DE804': 'Schwerin, Kreisfreie Stadt',
#  'DE80J': 'Mecklenburgische Seenplatte',
#  'DE80K': 'Landkreis Rostock',
#  'DE80L': 'Vorpommern-Rügen',
#  'DE80M': 'Nordwestmecklenburg',
#  'DE80N': 'Vorpommern-Greifswald',
#  'DE80O': 'Ludwigslust-Parchim',
#  'DED41': 'Chemnitz, Kreisfreie Stadt',
#  'DED42': 'Erzgebirgskreis',
#  'DED43': 'Mittelsachsen',
#  'DED44': 'Vogtlandkreis',
#  'DED45': 'Zwickau',
#  'DED21': 'Dresden, Kreisfreie Stadt',
#  'DED2C': 'Bautzen',
#  'DED2D': 'Görlitz',
#  'DED2E': 'Meißen',
#  'DED2F': 'Sächsische Schweiz-Osterzgebirge',
#  'DED51': 'Leipzig, Kreisfreie Stadt',
#  'DED52': 'Leipzig',
#  'DED53': 'Nordsachsen',
#  'DEE01': 'Dessau-Roßlau, Kreisfreie Stadt',
#  'DEE02': 'Halle (Saale), Kreisfreie Stadt',
#  'DEE03': 'Magdeburg, Kreisfreie Stadt',
#  'DEE04': 'Altmarkkreis Salzwedel',
#  'DEE05': 'Anhalt-Bitterfeld',
#  'DEE07': 'Börde',
#  'DEE08': 'Burgenlandkreis',
#  'DEE09': 'Harz',
#  'DEE06': 'Jerichower Land',
#  'DEE0A': 'Mansfeld-Südharz',
#  'DEE0B': 'Saalekreis',
#  'DEE0C': 'Salzlandkreis',
#  'DEE0D': 'Stendal',
#  'DEE0E': 'Wittenberg',
#  'DEG01': 'Erfurt, Kreisfreie Stadt',
#  'DEG02': 'Gera, Kreisfreie Stadt',
#  'DEG03': 'Jena, Kreisfreie Stadt',
#  'DEG04': 'Suhl, Kreisfreie Stadt',
#  'DEG05': 'Weimar, Kreisfreie Stadt',
#  'DEG0N': 'Eisenach, Kreisfreie Stadt',
#  'DEG06': 'Eichsfeld',
#  'DEG07': 'Nordhausen',
#  'DEG0P': 'Wartburgkreis',
#  'DEG09': 'Unstrut-Hainich-Kreis',
#  'DEG0A': 'Kyffhäuserkreis',
#  'DEG0B': 'Schmalkalden-Meiningen',
#  'DEG0C': 'Gotha',
#  'DEG0D': 'Sömmerda',
#  'DEG0E': 'Hildburghausen',
#  'DEG0F': 'Ilm-Kreis',
#  'DEG0G': 'Weimarer Land',
#  'DEG0H': 'Sonneberg',
#  'DEG0I': 'Saalfeld-Rudolstadt',
#  'DEG0J': 'Saale-Holzland-Kreis',
#  'DEG0K': 'Saale-Orla-Kreis',
#  'DEG0L': 'Greiz',
#  'DEG0M': 'Altenburger Land'}

# %% [markdown]
# ## Modules `data.py` and `plot.py`

# %% [markdown]
# The `data.py`-module is resposible for providing
# - all relevant datasets (dimensionless, spatial, temporal and spatiotemporal) in a clear and structured manner,
# - access the demandregio-database in a comfortable way and
# - some handy utility functions.
#
# The `plot.py`-module provides plotting functions such as
# - spatial data: geographical choropleth maps
# - temporal data: multidimensional line/bar/scatter charts
# - spatiotemporal data: animations.

# %%
from disaggregator import data, plot

# %% [markdown]
# The demandregio database contains both **spatial** and **temporal** datasets.
#
# To have a look, what different **spatial datasets** are available, we do:

# %%
df_spatial = data.database_description('spatial')
df_spatial
# Out:
#                                                         title  \
# id_spatial
# 1                                   Einwohnerzahl, 1997..2017
# 2                Stromverbrauch private Haushalte, 1991..2018
# 3                     Stromverbrauch je Einwohner, 1997..2017
# 4               Stromverbrauch privater Haushalte, 1997..2017
# 5                                        Heizstrukturen (Lkr)
# 6                                Wirtschaftsentwicklung (BWS)
# 7                                Wirtschaftsentwicklung (BIP)
# 8                               Bevölkerungsentwicklung (NEP)
# 9                                         Nettostromverbrauch
# 11                 Erwerbspersonen: Arbeitsmarktprognose 2013
# 12                               Wohnfläche private Haushalte
# 13                         Stromverbrauch nach Haushaltsgröße
# 14                       Anzahl Haushalte nach Haushaltsgröße
# 15                   Energieverwendung in der Industrie je LK
# 16          Energetischer und nicht-energetischer Einsatz ...
# 17          Sozialversicherungspflichtig Beschäftigte nach...
# 18          Synthese: Sozialversicherungspflichtig Beschäf...
# 19          Sozialversicherungspflichtig Beschäftigte, Sze...
# 20          Sozialversicherungspflichtig Beschäftigte, Sze...
# 21                         Stromverbrauch der Industrie je WZ
# 22                    Stromerzeugungsanlagen in der Industrie
# 23          Synthese: Stromerzeugungsanlagen in der Indust...
# 25          Stromverbrauch Industrie je LK und WZ (Verbrau...
# 26           Raumordnungsprognose 2035 - Bevölkerungsprognose
# 27          Synthese: Soz. Beschäftigte je LK nach WZ und ...
# 28          Synthese: Soz. Beschäftigte je LK nach WZ und ...
# 35                                 Gasverbrauch der Haushalte
# 36                                    Energieverbrauch Kochen
# 37                Warmwasserbereitstellung nach Energieträger
# 38          Umweltökonomische Gesamtrechnung, Tabelle 3.2.3.4
# 39                                            Landkreisfläche
# 40                               Anzahl Haushalte, 1990..2030
# 41           Anzahl Haushalte nach Haushaltsgröße, 1990..2030
# 42                                Erwerbspersonen, 1990..2030
# 43                                    Bevölkerung, 1990..2030
# 44              Erwerbspersonen nach Altersgruppe, 1990..2030
# 45                                      Verfügbares Einkommen
# 46                     Bevölkerung Fortschreibung, 1990..2060
# 47                 IWU Deutsche Wohngebäudetypologie Mannheim
# 48                                    Bevölkerung, 1997..2060
# 49                               Anzahl Haushalte, 1990..2060
# 50           Anzahl Haushalte nach Haushaltsgröße, 1997..2060
# 53               Synthese: Stromverbrauch der Industrie je WZ
# 54          Synthese: Stromerzeugungsanlagen in der Industrie
# 55          Stromverbrauch der Haushalte nach Haushaltsgro...
# 56          IWU Deutsche Wohngebäudetypologie (alle LK und...
# 57          Fortschreibung der mit Gas beheizten Wohnfläch...
#
#                                             description_short region_types  \
# id_spatial
# 1                              Einwohnerzahl zum Stand 31.12.         [lk]
# 2           Stromverbrauch der privaten Haushalte nach BMW...       [land]
# 3           spezifischer Stromverbrauch je Einwohner nach ...       [land]
# 4                       Stromverbrauch der privaten Haushalte         [lk]
# 5            Heizstrukturen auf Landkreisebene je Wohneinheit         [lk]
# 6           Wirtschaftsentwicklung (BWS), Bruttowertschöpf...       [land]
# 7           Wirtschaftsentwicklung (BIP), Bruttoinlandspro...       [land]
# 8           Bevölkerungsentwicklung (NEP, Tabelle 26), nac...       [land]
# 9           Klassischer Nettostromverbrauch inkl. VNB-Netz...       [land]
# 11          Erwerbspersonen: Arbeitsmarktprognose 2030. Di...       [land]
# 12          Wohnfläche nach Heizstruktur, Gebäudetyp, Baua...         [lk]
# 13          Stromverbrauch je Haushalt nach Haushaltsgröße...       [land]
# 14          Anzahl der privaten Haushalte nach Größe des H...         [lk]
# 15          Energieverwendung der Betriebe des Verarbeiten...         [lk]
# 16          Energetischer und nicht-energetischer Einsatz ...         [lk]
# 17          Sozialversicherungspflichtig Beschäftigte nach...         [lk]
# 18          Synthese: Sozialversicherungspflichtig Beschäf...         [lk]
# 19          Fortschreibung der Sozialversicherungspflichti...         [lk]
# 20          Fortschreibung der Sozialversicherungspflichti...         [lk]
# 21          Energieverwendung der Betriebe des Verarb. Gew...       [land]
# 22          Stromerzeugungsanlagen der Betriebe im Verarbe...       [land]
# 23          Synthese: Stromerzeugungsanlagen der Betriebe ...       [land]
# 25          Berechnung des Stromverbrauchs in der Industri...         [lk]
# 26          Raumordnungsprognose 2035 - Tabellen zur Bevöl...         [lk]
# 27          Synthese: Sozialversicherungspflichtig Beschäf...         [lk]
# 28          Synthese: Sozialversicherungspflichtig Beschäf...         [lk]
# 35          Gasverbrauch der Haushalte (DE) nach Anwendung...       [land]
# 36          Energieverbrauch Kochen: Anteil Strom und Gas ...         [bl]
# 37                Warmwasserbereitstellung nach Energieträger         [bl]
# 38          Umweltökonomische Gesamtrechnung, Tabelle 3.2....       [land]
# 39          Landkreisfläche basierend auf den Geodaten (vg...         [lk]
# 40                                                HH_Krs_Insg         [lk]
# 41                                               HH_Krs_4HHgr         [lk]
# 42                                               EWP_Krs_Insg         [lk]
# 43                                                Bev_Krs_5Ak         [lk]
# 44                                                EWP_Krs_3Ak         [lk]
# 45          Verfügbares Einkommen der privaten Haushalte e...         [lk]
# 46          Fortschreibung der Bevölkerung 2019 - 2060 auf...         [bl]
# 47          IWU Deutsche Wohngebäudetypologie Mannheim, ko...         [lk]
# 48                 Bevölkerung Vorausberechnung 2019 bis 2060         [lk]
# 49                                                HH_Krs_Insg         [lk]
# 50                                               HH_Krs_4HHgr         [lk]
# 53          Synthese: Energieverwendung der Betriebe des V...       [land]
# 54          Synthese: Stromerzeugungsanlagen der Betriebe ...       [land]
# 55          Stromverbrauch der Haushalte insgesamt und nac...         [lk]
# 56          IWU Deutsche Wohngebäudetypologie Mannheim, ko...         [lk]
# 57          Fortschreibung der Wohnfläche nach Heizstruktu...         [lk]
#
#                                       internal_id_description  \
# id_spatial
# 1                                                         NaN
# 2                                                         NaN
# 3                                                         NaN
# 4                                                         NaN
# 5           internal_id[1] = Heizsystem (bzw. Energieträge...
# 6                                                         NaN
# 7                                                         NaN
# 8                                                         NaN
# 9                                                         NaN
# 11                                                        NaN
# 12          internal_id[1] = id_gt Gebäudetyp: 1: EFH, 2: ...
# 13          internal_id[1] = hh_groesse: 0 alle, 1..5 Anza...
# 14          internal_id[1] = Haushaltsgröße\r\n0 = Insgesa...
# 15          internal_id[1]=1: Gesamt\r\ninternal_id[1]=2: ...
# 16          internal_id[0,1]={4,1}: Erdgas, nicht-energeti...
# 17          internal_id[1] = Monat der Erfassung (6 oder 9...
# 18          internal_id[1] = Monat der Erfassung (6 oder 9...
# 19          internal_id[1] = WZ2008 (siehe auch http://ope...
# 20          internal_id[1] = WZ2008 (siehe auch http://ope...
# 21          internal_id[1] = WZ2008 (05..33) (siehe auch h...
# 22          internal_id[1] = WZ2008 (05,08,10,13,16,17,19,...
# 23          internal_id[1] = WZ2008 (05..33) (siehe auch h...
# 25          internal_id[1] = WZ2008 (05..33) (siehe auch h...
# 26                                                         --
# 27                                    internal_id[1] = WZ2008
# 28                                    internal_id[1] = WZ2008
# 35          internal_id[1]: 1 = Raumwärme; 2 = Warmwasser;...
# 36          internal_id[1]: 1 = Strom; 2 = Gas\r\ninternal...
# 37          internal_id[1]: 1 = zentrale Bereitstellung; 2...
# 38          internal_id[1]: Wirtschaftszweig: 1=A; 2=01; 3...
# 39                                                        NaN
# 40                                                        NaN
# 41          internal_id [1]= Insgesamt\r\ninternal_id [2]=...
# 42                                                        NaN
# 43          internal_id[1]: 1 = 0 bis unter 20 Jahren; 2 =...
# 44          internal_id[1]: 1 = bis unter 30 Jahren; 2 = 3...
# 45          internal_id[1]: 1=verfügbares Einkommen (Summe...
# 46          internal_id[1]: 1 = Geburten und LE moderat, W...
# 47          internal_id[1] = Gebäudetyp: 1: EFH, 2: RH, 3:...
# 48          internal_id[1]: 0 = Historische Daten (id_spat...
# 49                                                        NaN
# 50          internal_id[1]: 1 = Insgesamt\r\ninternal_id[1...
# 53          internal_id[1] = WZ2008 (05..33) (siehe auch h...
# 54          internal_id[1] = WZ2008 (05,08,10,13,16,17,19,...
# 55          internal_id[1] = HH-Größe: 1 = Insgesamt; 2 = ...
# 56          internal_id[1] = Gebäudetyp: 1: EFH, 2: RH, 3:...
# 57          internal_id[1] = id_gt Gebäudetyp: 1: EFH, 2: ...
#
#                               units  \
# id_spatial
# 1                         Einwohner
# 2                               MWh
# 3                     MWh/Einwohner
# 4                               MWh
# 5              Anzahl Wohneinheiten
# 6                         Mrd. Euro
# 7                         Mrd. Euro
# 8                         Einwohner
# 9                               TWh
# 11                  Erwerbspersonen
# 12                 Wohnfläche in m²
# 13                            kWh/a
# 14                        Haushalte
# 15                          Tsd. MJ
# 16                          Tsd. MJ
# 17                     Beschäftigte
# 18                     Beschäftigte
# 19                     Beschäftigte
# 20                     Beschäftigte
# 21                              MWh
# 22                              GWh
# 23                              GWh
# 25                              GWh
# 26                        Einwohner
# 27                     Beschäftigte
# 28                     Beschäftigte
# 35                              MWh
# 36                                %
# 37                                %
# 38                               TJ
# 39                              km²
# 40          Haushalte pro Landkreis
# 41                              NaN
# 42                              NaN
# 43                              NaN
# 44                              NaN
# 45                             Euro
# 46                        Einwohner
# 47                        kWh/(m2a)
# 48                        Einwohner
# 49          Haushalte pro Landkreis
# 50                              NaN
# 53                              MWh
# 54                              GWh
# 55                            kWh/a
# 56                        kWh/(m2a)
# 57                 Wohnfläche in m²
#
#                                                         years
# id_spatial
# 1           [1997, 1998, 1999, 2000, 2001, 2002, 2003, 200...
# 2           [1991, 1992, 1993, 1994, 1995, 1996, 1997, 199...
# 3           [1997, 1998, 1999, 2000, 2001, 2002, 2003, 200...
# 4           [1997, 1998, 1999, 2000, 2001, 2002, 2003, 200...
# 5                                                      [2018]
# 6                              [2012, 2020, 2030, 2040, 2050]
# 7                              [2012, 2020, 2030, 2040, 2050]
# 8                              [2012, 2020, 2030, 2040, 2050]
# 9                                    [2008, 2013, 2015, 2030]
# 11                                         [2010, 2020, 2030]
# 12                                               [2011, 2018]
# 13                                                     [2015]
# 14                                                     [2011]
# 15          [2003, 2004, 2005, 2006, 2007, 2008, 2009, 201...
# 16          [2008, 2009, 2010, 2011, 2012, 2013, 2014, 201...
# 17          [2008, 2009, 2010, 2011, 2012, 2013, 2014, 201...
# 18          [2008, 2009, 2010, 2011, 2012, 2013, 2014, 201...
# 19                                               [2014, 2030]
# 20                                               [2014, 2030]
# 21          [2008, 2009, 2010, 2011, 2012, 2013, 2014, 201...
# 22          [2008, 2009, 2010, 2011, 2012, 2013, 2014, 201...
# 23          [2008, 2009, 2010, 2011, 2012, 2013, 2014, 201...
# 25          [2008, 2009, 2010, 2011, 2012, 2013, 2014, 201...
# 26          [2012, 2013, 2014, 2015, 2016, 2017, 2018, 201...
# 27          [2012, 2013, 2014, 2015, 2016, 2017, 2018, 201...
# 28          [2012, 2013, 2014, 2015, 2016, 2017, 2018, 201...
# 35          [2008, 2009, 2010, 2011, 2012, 2013, 2014, 201...
# 36
# 37
# 38                                                     [2015]
# 39          [1997, 1998, 1999, 2000, 2001, 2002, 2003, 200...
# 40          [1990, 1991, 1992, 1993, 1994, 1995, 1996, 199...
# 41          [1990, 1991, 1992, 1993, 1994, 1995, 1996, 199...
# 42          [1990, 1991, 1992, 1993, 1994, 1995, 1996, 199...
# 43          [1990, 1991, 1992, 1993, 1994, 1995, 1996, 199...
# 44          [1990, 1991, 1992, 1993, 1994, 1995, 1996, 199...
# 45          [2000, 2001, 2002, 2003, 2004, 2005, 2006, 200...
# 46          [2019, 2020, 2021, 2022, 2023, 2024, 2025, 202...
# 47                                                     [2014]
# 48          [1997, 19981999, 2000, 2001, 2002, 2003, 2004,...
# 49          [1990, 1991, 1992, 1993, 1994, 1995, 1996, 199...
# 50          [1990, 1991, 1992, 1993, 1994, 1995, 1996, 199...
# 53          [2008, 2009, 2010, 2011, 2012, 2013, 2014, 201...
# 54          [2008, 2009, 2010, 2011, 2012, 2013, 2014, 201...
# 55          [1990, 1991, 1992, 1993, 1994, 1995, 1996, 199...
# 56          [2006, 2007, 2008, 2009, 2010, 2011, 2012, 201...
# 57                                               [2018, 2030]

# %% [markdown]
# ... and for **temporal datasets** we do:

# %%
df_temporal = data.database_description('temporal')
df_temporal
# Out:
#                                                          title  \
# id_temporal
# 1                                        Wochentag, 1995..2060
# 2                     Meteorologische Jahreszeiten, 1995..2060
# 3                                             Stunde des Tages
# 4                                        Standartlastprifil H0
# 5                                        Standartlastprifil H0
# 6                                       Private Haushalte (H0)
# 8                                              Globalstrahlung
# 9                                   Tag des Jahres, 1995..2060
# 10                          Dynamisierungsfunktion, 1995..2060
# 11                                             Außentemperatur
# 12                                             Außentemperatur
# 13                                                  Sonnenhöhe
# 14                                                 Beleuchtung
# 15                                            Anteil Grundlast
# 16                                          Anteil Anwendungen
# 17                                             Globalstrahlung
# 18                                                Ferienzeiten
# 19                                       Feiertage, 2007..2060
# 20                                                      SLP G0
# 21                                                      SLP G0
# 22                                                      SLP G0
# 23                                                      SLP H0
# 24                                                      SLP H0
# 25           Stündliches Lastprofil privater Haushalte (H0)...
# 26           Stündlicher Stromverbrauch privater Haushalte,...
#
#                                              description_short region_types  \
# id_temporal
# 1                              Zeitstrahl mit den Wochentagen        [land]
# 2            Meteorologische Jahreszeiten (Dez-Feb: 1, Mrz-...       [land]
# 3                        Stunde des Tages (mit Zeitumstellung)       [land]
# 4            Standardlastprofil (H0) private Haushalte (15 ...       [land]
# 5            Standardlastprofil (H0) private Haushalte (1 S...       [land]
# 6            Lastgang der privaten Haushalte nach H0 (1 Std...       [land]
# 8                            Globalstrahlung nach CAMS (1 Std)         [lk]
# 9            Tag des Jahres: 1..365/366 in stündlicher Aufl...       [land]
# 10           Dynamisierungsfunktion für das SLP H0. Werte i...       [land]
# 11           Außentemperatur, Landkreise; basierend auf Mit...         [lk]
# 12           Außentemperatur, Landkreise; basierend auf grö...         [lk]
# 13           Sonnenhöhe, Landkreise; basierend auf größter ...         [lk]
# 14           Beleuchtung, Landkreise; basierend auf größter...         [lk]
# 15           Sektor Private Haushalte: Grundlastanteil für ...       [land]
# 16           Sektor Private Haushalte: Anteile für verschie...       [land]
# 17                      Globalstrahlung nach CAMS (15 Minuten)         [lk]
# 18           Schulferien in den Bundesländern (bereitgestel...     [bl, lk]
# 19           Feiertage in den Bundesländern (bereitgestellt...         [lk]
# 20           Standardlastprofil (G0) Gewerbe, allgemein (15...       [land]
# 21           Standardlastprofil (G0) Gewerbe, allgemein (1 ...       [land]
# 22           Standardlastprofil (G0) Gewerbe, allgemein (1 ...         [lk]
# 23           Lastgang der privaten Haushalte nach H0 (1 Jah...         [lk]
# 24           Lastgang der privaten Haushalte nach H0 (1 Jah...         [lk]
# 25           Lastgang der privaten Haushalte nach H0 (1 Std...         [lk]
# 26           Lastgang der privaten Haushalte nach H0 skalie...         [lk]
#
#                                        internal_id_description  \
# id_temporal
# 1                                                          NaN
# 2                                                          NaN
# 3                                                          NaN
# 4            [season (1..4), day (1..7), hh (0..23), mm (0....
# 5                      [season (1..4), day (1..7), hh (0..23)]
# 6                                                          NaN
# 8                                                          NaN
# 9                                                          NaN
# 10                                                         NaN
# 11           internal_id = 1: stündliche Auflösung\r\ninter...
# 12           internal_id = 1: stündliche Auflösung\r\ninter...
# 13                                                         NaN
# 14           Sonnenhöhe(id_temporal = 14) als Schwellwert:\...
# 15           [hh_groesse, anwendung]\r\nhh_groesse: 0 alle,...
# 16           [hh_groesse, anwendung]\r\nhh_groesse: 0 alle,...
# 17                                                         NaN
# 18                                                         NaN
# 19                                                         NaN
# 20           [season (1..4), day (1..7), hh (0..23), mm (0....
# 21                     [season (1..4), day (1..7), hh (0..23)]
# 22                                                         NaN
# 23                                                         NaN
# 24                                                         NaN
# 25                                                         NaN
# 26           Szenarien der Bevölkerungsentwicklung: interna...
#
#                                   units time_step  years_step  \
# id_temporal
# 1                             Wochentag     1 Std         nan
# 2                            Jahreszeit     1 Std         nan
# 3                                Stunde     1 Std         nan
# 4                                   NaN    15 Min         nan
# 5                                   NaN     1 Std         nan
# 6                                MW/MWh     1 Std         nan
# 8                                 Wh/m2     1 Std         nan
# 9                        Tag des Jahres     1 Std         nan
# 10                 Dynamisierungsfaktor     1 Std         nan
# 11                                   °C     1 Std         nan
# 12                                   °C     1 Std         nan
# 13                                    °     1 Std         nan
# 14                                  1/0     1 Std         nan
# 15                               Anteil       NaN         nan
# 16                               Anteil       NaN         nan
# 17                                Wh/m2    15 Min         nan
# 18           1: Ferien; 0: keine Ferien     1 Std         nan
# 19              1: Feiertag; 0: Werktag     1 Std         nan
# 20                                  NaN    15 Min         nan
# 21                                  NaN     1 Std         nan
# 22                               MW/MWh     1 Std         nan
# 23                               MW/MWh     1 Std         nan
# 24                               MW/MWh     1 Std         nan
# 25                                  NaN     1 Std         nan
# 26                               MW/MWh     1 Std         nan
#
#                                                  years_weather
# id_temporal
# 1            [1995, 1996, 1997, 1998, 1999, 2000, 2001, 200...
# 2            [1995, 1996, 1997, 1998, 1999, 2000, 2001, 200...
# 3            [1995, 1996, 1997, 1998, 1999, 2000, 2001, 200...
# 4
# 5
# 6            [1995, 1996, 1997, 1998, 1999, 2000, 2001, 200...
# 8            [2005, 2006, 2007, 2008, 2009, 2010, 2011, 201...
# 9            [1995, 1996, 1997, 1998, 1999, 2000, 2001, 200...
# 10           [1995, 1996, 1997, 1998, 1999, 2000, 2001, 200...
# 11           [2006, 2007, 2008, 2009, 2010, 2011, 2012, 201...
# 12           [2006, 2007, 2008, 2009, 2010, 2011, 2012, 201...
# 13           [2006, 2007, 2008, 2009, 2010, 2011, 2012, 201...
# 14           [2006, 2007, 2008, 2009, 2010, 2011, 2012, 201...
# 15
# 16
# 17           [2005, 2006, 2007, 2008, 2009, 2010, 2011, 201...
# 18           [2004, 2005, 2006, 2007, 2008, 2009, 2010, 201...
# 19           [2000, 2001, 2002, 2003, 2004, 2005, 2006, 200...
# 20
# 21
# 22           [2000, 2001, 2002, 2003, 2004, 2005, 2006, 200...
# 23           [2000, 2001, 2002, 2003, 2004, 2005, 2006, 200...
# 24           [2000, 2001, 2002, 2003, 2004, 2005, 2006, 200...
# 25           [2007, 2008, 2009, 2010, 2011, 2012, 2013, 201...
# 26           [2007, 2008, 2009, 2010, 2011, 2012, 2013, 201...

# %% [markdown]
# Load **population** per region. This dataset is one-dimensional and returned as a ``pandas.Series`` see here:

# %%
df_pop = data.population()
df_pop.head()
# Out:
# nuts3
# DE111    623738
# DE112    381281
# DE113    524127
# DE114    252749
# DE115    534074
# Name: value, dtype: int64

# %% [markdown]
# Load **household sizes** per region. This dataset is two-dimensional and returned as a ``pandas.DataFrame`` see here:

# %%
df_HH = data.households_per_size()
df_HH.head()
# Out:
# hh_size       1      2      3      4     5     6
# nuts3
# DE111    137719  92772  37918  27768  9507  4684
# DE112     54428  53829  25284  22383  7146  3012
# DE113     81435  76939  34430  29628  8930  3726
# DE114     34850  35921  17152  14745  4701  2017
# DE115     81426  80782  34042  30250  9038  3793

# %% [markdown]
# So single-households are in column ``1``, households /w two persons are in column ``2`` and so on...
# ***Please note***: Column ``6`` contains all household sizes with more than five persons.

# %% [markdown]
# Now, it could happen that you think that the values in one region are somewhat remarkable or special (very high, very low, variating in size...) in contrast to the surroung regions, e.g.:

# %%
df_HH.loc['DE27D':'DE402']
# Out:
# hh_size       1       2       3       4      5      6
# nuts3
# DE27D     15136   15581    8976    8452   3223   1364
# DE27E     24415   22718    9287    8370   2865   1190
# DE300    941959  593799  211718  115622  35369  19329
# DE401     15992   14478    4917    2095    463    195
# DE402     23910   19369    6826    2901    652    281

# %% [markdown]
# As you can see region with nuts3-ID `DE300` is a lot higher than the two around. For this case, it is useful to quickly get to know the name of that regions for a better unterstanding. This can be done easily with the function `append_region_name(df)`:

# %%
data.append_region_name(df_HH.loc['DE27D':'DE402'])
# Out:
# hh_size       1       2       3       4      5      6  \
# nuts3
# DE27D     15136   15581    8976    8452   3223   1364
# DE27E     24415   22718    9287    8370   2865   1190
# DE300    941959  593799  211718  115622  35369  19329
# DE401     15992   14478    4917    2095    463    195
# DE402     23910   19369    6826    2901    652    281
#
# hh_size                                 region_name
# nuts3
# DE27D                                    Donau-Ries
# DE27E                                    Oberallgäu
# DE300                                        Berlin
# DE401    Brandenburg an der Havel, Kreisfreie Stadt
# DE402                     Cottbus, Kreisfreie Stadt

# %% [markdown]
# Or, a bit more elegant and pythonic, just like this:

# %%
df_HH.loc['DE27D':'DE402'].pipe(data.append_region_name)
# Out:
# hh_size       1       2       3       4      5      6  \
# nuts3
# DE27D     15136   15581    8976    8452   3223   1364
# DE27E     24415   22718    9287    8370   2865   1190
# DE300    941959  593799  211718  115622  35369  19329
# DE401     15992   14478    4917    2095    463    195
# DE402     23910   19369    6826    2901    652    281
#
# hh_size                                 region_name
# nuts3
# DE27D                                    Donau-Ries
# DE27E                                    Oberallgäu
# DE300                                        Berlin
# DE401    Brandenburg an der Havel, Kreisfreie Stadt
# DE402                     Cottbus, Kreisfreie Stadt

# %% [markdown]
# So after this step it becomes clear, why these region's values are that high: It is simply Berlin, the biggest city.

# %% [markdown]
# One further important dataset is that containing the **living spaces in [m²]** by _building type_ for each region.
# building types:
# - `1FH`: one family house
# - `2FH`: two family house
# - `MFH_03_06`: multi family house for 3-6 families
# - `MFH_07_12`: multi family house for 7-12 families
# - `MFH_13_99`: multi family house for >12 families

# %%
df_ls = data.living_space()
df_ls.head()
# Out:
# building_type           1FH           2FH     MFH_03_06     MFH_07_12  \
# nuts3
# DE111         3,403,625.308 2,081,552.620 7,937,327.979 6,709,143.483
# DE112         6,197,581.782 3,432,353.189 3,655,280.346 2,423,037.851
# DE113         8,000,477.151 4,431,817.922 6,000,478.451 3,206,198.219
# DE114         4,434,813.337 2,800,773.607 2,425,602.059 1,101,553.139
# DE115         8,145,412.955 4,317,894.489 5,876,110.894 3,531,068.340
#
# building_type     MFH_13_99
# nuts3
# DE111         3,507,993.171
# DE112         1,543,024.838
# DE113         1,481,549.456
# DE114           490,994.703
# DE115         1,632,806.086

# %% [markdown]
# Now let's plot these datasets as a choropleth map:

# %%
fig, ax = plot.choropleth_map(df_pop/1e6, relative=False, unit='Mio. cap', axtitle='Population absolute')

# %% [markdown]
# As you can see, this is an <u>absolute</u> illustration, as it just shows the number of persons living in each region.
#
# Though this might be the most intuitive way, it contains **two severe problems**:
# 1. Since the population in the biggest city (Berlin) is almost *twice as big* as in the second-largest city of Hamburg and more than 3 times bigger as in the fourth-largest city (Cologne), but most of the rural areas have **way less** residents, the colorbar scaling does not provide good information.
#
#
# 2. The illustration does not take into account the size of the different regions. So, even if $-$ theoretically $-$ all people would be distributed equally over Germany, bigger regions would always show more residents than smaller ones.
#
# The **solution** is a <u>relative</u> illustration, showing the population per region as a proportion of the underlying area size in square-kilometers:

# %%
fig, ax = plot.choropleth_map(df_pop, relative=True, unit='cap', axtitle='Population relative per km²')

# %% [markdown]
# Now, this graphic shows a lot better, which areas are more densely and which are less densely populated.
#
# However, the two largest cities (Berlin and Munich) with ~4000+ residents/km² still kind of stick out. If we want to learn, where other densely populated areas are, it might be helpful to limit the colorization interval from zero to 3000:

# %%
fig, ax = plot.choropleth_map(df_pop, relative=True, unit='cap', axtitle='Population relative', interval=(0,3000))

# %% [markdown]
# Now let's plot the households on a map:

# %%
fig, ax = plot.choropleth_map(df_HH, relative=True, unit='households', axtitle='Households /w', colorbar_each_subplot=True, add_percentages=False)

# %% [markdown]
# As you can see, the framework recognizes automatically that this dataset contains several data columns and creates a subplot for each column.
# Still, it might be that you are not interested in the distribution of each household size, but the sum of all, e.g. to compare if the distribution of households corresponds to the distribution of the population. Let's do this:

# %%
fig, ax = plot.choropleth_map(df_HH.sum(axis=1), relative=True, unit='households', axtitle='Sum of Households')

# %% [markdown]
# So what about the living space distribution. Is it comparable to the households?

# %%
fig, ax = plot.choropleth_map(df_ls, relative=True, unit='m²', axtitle='Living spaces in', colorbar_each_subplot=True)

# %% [markdown]
# Now let's have a look at the **income distribution**:

# %%
df_inc = data.income(by='population')
df_inc.head()
# Out:
# nuts3
# DE111    24672
# DE112    24100
# DE113    24441
# DE114    23455
# DE115    24671
# Name: value, dtype: int64

# %%
fig, ax = plot.choropleth_map(df_inc/1e3, relative=False, unit='1000 €/cap.', axtitle='Income per capita')

# %% [markdown]
# Now save this figure e.g. as PDF file:

# %%
from disaggregator.config import _data_out
#fig.savefig(_data_out('income_distribution.pdf'), bbox_inches='tight')

# %% [markdown]
# By the way, it is always possible to change the underlying colormap:

# %%
fig, ax = plot.choropleth_map(df_inc/1e3, relative=False, unit='1000 €/cap.', axtitle='Income per capita', cmap='gist_rainbow')
