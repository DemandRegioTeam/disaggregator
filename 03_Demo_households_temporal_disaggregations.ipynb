# %%
from disaggregator import config, data, spatial, temporal, plot
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Power by 'Time Use Survey' (ZVE, only 2015)

# %% [markdown]
# Get spatial data in [MWh] that shall be disaggregated temporally

# %%
df_spat = spatial.disagg_households_power('population', weight_by_income=True) * 1e3
df_spat
# Out:
# nuts3
# DE111    1.162713e+06
# DE112    6.942694e+05
# DE113    9.678796e+05
# DE114    4.479099e+05
# DE115    9.955292e+05
#              ...
# DEG0K    1.156523e+05
# DEG0L    1.437641e+05
# DEG0M    1.262784e+05
# DEG0N    5.985672e+04
# DEG0P    1.821599e+05
# Name: value, Length: 401, dtype: float64

# %% [markdown]
# Calculate temporal distribution keys based on the ZVE. They will be saved in your `data_out` folder. This step can take up to 60 Minutes but is only necessary once.

# %%
temporal.make_zve_load_profiles()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# disaggregator.temporal: INFO     Creating ZVE-profile for Stuttgart (DE111)
# disaggregator.temporal: INFO     Calc load profile for household-size: 1
# disaggregator.temporal: INFO     Calc load profile for household-size: 2
# disaggregator.temporal: INFO     Calc load profile for household-size: 3
# disaggregator.temporal: INFO     Calc load profile for household-size: 4
# disaggregator.temporal: INFO     Calc load profile for household-size: 5
# disaggregator.temporal: INFO     ...creating hourly load profile for entire year...
# disaggregator.temporal: INFO     Creating ZVE-profile for Böblingen (DE112)
# disaggregator.temporal: INFO     Calc load profile for household-size: 1
# disaggregator.temporal: INFO     Calc load profile for household-size: 2
# disaggregator.temporal: INFO     Calc load profile for household-size: 3
# disaggregator.temporal: INFO     Calc load profile for household-size: 4
# disaggregator.temporal: INFO     Calc load profile for household-size: 5
# disaggregator.temporal: INFO     ...creating hourly load profile for entire year...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-7fb1a56b28c9> in <module>
# ----> 1 temporal.make_zve_load_profiles()
#
# Z:\PRO\PRO_DemandRegio\Arbeitsbereich_indiv\PV\Git\demandregio_github\disaggregator\temporal.py in make_zve_load_profiles(return_profile_by_typeday, return_profile_by_application, **kwargs)
#     248             ind = df_new.loc[i, 'Hour']
#     249             col = (df_new.loc[i, 'TypeDay'], df_new.loc[i, 'Season'])
# --> 250             df_new.loc[i, 'value'] = df_erg.loc[ind, col]
#     251         # generate distribution keys
#     252         df_new = df_new['value'] / df_new['value'].sum()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in __setitem__(self, key, value)
#     668
#     669         iloc = self if self.name == "iloc" else self.obj.iloc
# --> 670         iloc._setitem_with_indexer(indexer, value)
#     671
#     672     def _validate_key(self, key, axis: int):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _setitem_with_indexer(self, indexer, value)
#    1763                 # scalar value
#    1764                 for loc in ilocs:
# -> 1765                     isetter(loc, value)
#    1766
#    1767         else:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in isetter(loc, v)
#    1688                 else:
#    1689                     # set the item, possibly having a dtype change
# -> 1690                     ser = ser.copy()
#    1691                     ser._mgr = ser._mgr.setitem(indexer=pi, value=v)
#    1692                     ser._maybe_update_cacher(clear=True)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in copy(self, deep)
#    5652         dtype: object
#    5653         """
# -> 5654         data = self._mgr.copy(deep=deep)
#    5655         self._clear_item_cache()
#    5656         return self._constructor(data).__finalize__(self, method="copy")
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in copy(self, deep)
#     801             new_axes = list(self.axes)
#     802
# --> 803         res = self.apply("copy", deep=deep)
#     804         res.axes = new_axes
#     805         return res
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, align_keys, **kwargs)
#     404                 applied = b.apply(f, **kwargs)
#     405             else:
# --> 406                 applied = getattr(b, f)(**kwargs)
#     407             result_blocks = _extend_blocks(applied, result_blocks)
#     408
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\blocks.py in copy(self, deep)
#     671         values = self.values
#     672         if deep:
# --> 673             values = values.copy()
#     674         return self.make_block_same_class(values, ndim=self.ndim)
#     675
#
# KeyboardInterrupt:

# %% [markdown]
# Then load the temporal distribution keys based on the ZVE:

# %%
df_temp = (pd.read_csv(config.data_out('ZVE_timeseries_AllRegions_2015.csv'),
                       engine='c', index_col=0, parse_dates=True,
                       infer_datetime_format=True)
              .pipe(data.transpose_spatiotemporal))
df_temp
# Out:
#            0         1         2         3         4         5         6     \
# DE111  0.000054  0.000045  0.000042  0.000041  0.000047  0.000076  0.000134
# DE112  0.000054  0.000045  0.000042  0.000041  0.000047  0.000076  0.000134
# DE113  0.000054  0.000045  0.000042  0.000041  0.000047  0.000076  0.000134
# DE114  0.000054  0.000045  0.000042  0.000041  0.000047  0.000076  0.000134
# DE115  0.000054  0.000045  0.000042  0.000041  0.000047  0.000076  0.000134
# ...         ...       ...       ...       ...       ...       ...       ...
# DEG0K  0.000053  0.000045  0.000042  0.000041  0.000047  0.000076  0.000134
# DEG0L  0.000053  0.000045  0.000042  0.000041  0.000047  0.000076  0.000134
# DEG0M  0.000053  0.000045  0.000042  0.000041  0.000047  0.000076  0.000134
# DEG0N  0.000053  0.000045  0.000042  0.000041  0.000047  0.000076  0.000134
# DEG0P  0.000053  0.000045  0.000042  0.000041  0.000047  0.000076  0.000134
#
#            7         8         9     ...     8750      8751      8752  \
# DE111  0.000144  0.000132  0.000121  ...  0.00011  0.000111  0.000136
# DE112  0.000144  0.000132  0.000121  ...  0.00011  0.000111  0.000136
# DE113  0.000144  0.000131  0.000120  ...  0.00011  0.000111  0.000136
# DE114  0.000144  0.000131  0.000120  ...  0.00011  0.000111  0.000136
# DE115  0.000144  0.000132  0.000121  ...  0.00011  0.000111  0.000136
# ...         ...       ...       ...  ...      ...       ...       ...
# DEG0K  0.000143  0.000131  0.000121  ...  0.00011  0.000114  0.000138
# DEG0L  0.000143  0.000131  0.000121  ...  0.00011  0.000114  0.000138
# DEG0M  0.000143  0.000131  0.000121  ...  0.00011  0.000115  0.000138
# DEG0N  0.000143  0.000132  0.000122  ...  0.00011  0.000114  0.000138
# DEG0P  0.000143  0.000132  0.000122  ...  0.00011  0.000114  0.000138
#
#            8753      8754      8755      8756      8757      8758      8759
# DE111  0.000173  0.000189  0.000191  0.000184  0.000174  0.000131  0.000079
# DE112  0.000173  0.000189  0.000191  0.000184  0.000174  0.000131  0.000079
# DE113  0.000173  0.000189  0.000191  0.000184  0.000174  0.000131  0.000079
# DE114  0.000173  0.000189  0.000191  0.000184  0.000174  0.000131  0.000079
# DE115  0.000173  0.000189  0.000191  0.000184  0.000174  0.000131  0.000079
# ...         ...       ...       ...       ...       ...       ...       ...
# DEG0K  0.000174  0.000188  0.000191  0.000184  0.000174  0.000131  0.000079
# DEG0L  0.000174  0.000188  0.000191  0.000184  0.000173  0.000131  0.000079
# DEG0M  0.000174  0.000188  0.000191  0.000184  0.000173  0.000131  0.000079
# DEG0N  0.000173  0.000188  0.000191  0.000184  0.000174  0.000131  0.000079
# DEG0P  0.000173  0.000188  0.000191  0.000184  0.000174  0.000131  0.000079
#
# [401 rows x 8760 columns]

# %% [markdown]
# The function `temporal.disagg_temporal()` needs two inputs:
# 1. **a spatial dataset**
#     either as `pd.Series` or `pd.DataFrame`: in both cases _NUTS-3-index'ed_
#
#
# 2. **a temporal dataset**
#     if passed as `pd.DataFrame`: _NUTS-3-index'ed_
#     if passed as `pd.Series`: _pd.DateTimeIndex'ed_
#
# Pre-check:
# * Both `df_spat` and `df_temp` are `pd.DataFrame`s
# * Both have NUTS-3-indices.
#
# So now we can directly perfom the disaggregation:

# %%
df_elc_tempo_ZVE = temporal.disagg_temporal(df_spat, df_temp)
df_elc_tempo_ZVE
# Out:
#             0          1          2          3          4          5     \
# DE111  62.243096  52.126232  49.009933  47.478387  55.075697  88.759143
# DE112  37.168059  31.126070  29.265026  28.350340  32.887385  53.002707
# DE113  51.814067  43.391955  40.797721  39.522726  45.847246  73.887590
# DE114  23.977962  20.080572  18.880060  18.290048  21.216790  34.192800
# DE115  53.291912  44.630502  41.962479  40.651284  47.155769  75.994112
# ...          ...        ...        ...        ...        ...        ...
# DEG0K   6.184371   5.181835   4.872785   4.721075   5.474694   8.816397
# DEG0L   7.686875   6.441060   6.056989   5.868472   6.805049  10.958076
# DEG0M   6.750356   5.656935   5.319789   5.154349   5.976532   9.622400
# DEG0N   3.200796   2.681904   2.521948   2.443429   2.833481   4.563034
# DEG0P   9.740952   8.161778   7.674979   7.436016   8.623073  13.886662
#
#              6           7           8           9     ...        8750  \
# DE111  155.867967  167.129661  152.972696  140.248072  ...  127.884639
# DE112   93.078833   99.804531   91.436438   83.775718  ...   76.361392
# DE113  129.753235  139.128452  127.261214  116.463387  ...  106.455208
# DE114   60.045343   64.345888   58.816884   53.726737  ...   49.264726
# DE115  133.450182  143.091755  131.013930  120.206915  ...  109.496528
# ...           ...         ...         ...         ...  ...         ...
# DEG0K   15.475622   16.567142   15.158041   13.976416  ...   12.720572
# DEG0L   19.234237   20.584787   18.828011   17.372849  ...   15.812597
# DEG0M   16.888233   18.073631   16.527329   15.258049  ...   13.889377
# DEG0N    8.009632    8.584622    7.885118    7.298413  ...    6.583629
# DEG0P   24.375760   26.133508   23.996802   22.203549  ...   20.035718
#
#              8751        8752        8753        8754        8755        8756  \
# DE111  129.204791  158.526482  200.867852  219.436620  222.137802  214.089070
# DE112   77.085460   94.527074  119.874115  131.041281  132.655255  127.849916
# DE113  107.554479  131.965348  167.266655  182.672132  184.921195  178.221492
# DE114   49.815212   61.112960   77.477955   84.534197   85.574870   82.474331
# DE115  110.672853  135.776451  171.978498  187.875086  190.187102  183.295229
# ...           ...         ...         ...         ...         ...         ...
# 1      3.728710   6.914674   5.398940   5.181835   6.441060   5.656935
# 2      3.506253   6.502229   5.077018   4.872785   6.056989   5.319789
# 3      3.397035   6.299755   4.919010   4.721075   5.868472   5.154349
# 4      3.939479   7.305491   5.704034   5.474694   6.805049   5.976532
# ...         ...        ...        ...        ...        ...        ...
# 8755  15.867765  29.421521  22.966677  22.046708  27.400320  24.056387
# 8756  15.290306  28.350323  22.129864  21.243819  26.402020  23.178993
# 8757  14.443807  26.780660  20.904432  20.067565  24.940035  21.895219
# 8758  10.872531  20.159370  15.736385  15.106155  18.774261  16.482779
# 8759   6.594222  12.227185   9.545127   9.162467  11.387739   9.998707
#
#           DEG0N      DEG0P
# 0      3.200796   9.740952
# 1      2.681904   8.161778
# 2      2.521948   7.674979
# 3      2.443429   7.436016
# 4      2.833481   8.623073
# ...         ...        ...
# 8755  11.410698  34.726370
# 8756  10.995180  33.461871
# 8757  10.386395  31.609157
# 8758   7.818490  23.794159
# 8759   4.742183  14.431925
#
# [8760 rows x 401 columns]

# %% [markdown]
# So let's take out one region, e.g. Berlin (DE300), and plot it as a line graph:

# %%
fig, ax = plt.subplots(figsize=(20, 4))
df_elc_tempo_ZVE['DE300'].plot(ax=ax)
plot.set_ax_format(ax=ax, xlim=(0, 8760), ylim=(0, None), ylabel='[MWh]', xlabel='Hour of Year',
                   axtitle='Power Consumption of Private Households in Berlin')

# %% [markdown]
# This depictation however does not provide a good visualization of what is happening on shorter timescales, i.e. within one day.
#
# Therefore, we choose to plot it as a heatmap:

# %%
fig, ax = plot.heatmap_timeseries(df_elc_tempo_ZVE['DE300'], clabel='[MWh]')

# %% [markdown]
# # Power by 'Standard Load Profiles' (SLP, all years)
# update Dec 2020

# %%
df_elec_temp_slp = temporal.disagg_temporal_power_housholds_slp(use_nuts3code=True, by='population', weight_by_income=False,  year=2016)
# Out:
# disaggregator.temporal: INFO     Working on state: SH.
# disaggregator.temporal: INFO     ... creating state-specific load-profiles
# disaggregator.temporal: INFO     ... assigning load-profiles
# disaggregator.temporal: INFO     Working on state: HH.
# disaggregator.temporal: INFO     ... creating state-specific load-profiles
# disaggregator.temporal: INFO     ... assigning load-profiles
# disaggregator.temporal: INFO     Working on state: NI.
# disaggregator.temporal: INFO     ... creating state-specific load-profiles
# disaggregator.temporal: INFO     ... assigning load-profiles
# disaggregator.temporal: INFO     Working on state: HB.
# disaggregator.temporal: INFO     ... creating state-specific load-profiles
# disaggregator.temporal: INFO     ... assigning load-profiles
# disaggregator.temporal: INFO     Working on state: NW.
# disaggregator.temporal: INFO     ... creating state-specific load-profiles
# disaggregator.temporal: INFO     ... assigning load-profiles
# disaggregator.temporal: INFO     Working on state: HE.
# disaggregator.temporal: INFO     ... creating state-specific load-profiles
# disaggregator.temporal: INFO     ... assigning load-profiles
# disaggregator.temporal: INFO     Working on state: RP.
# disaggregator.temporal: INFO     ... creating state-specific load-profiles
# disaggregator.temporal: INFO     ... assigning load-profiles
# disaggregator.temporal: INFO     Working on state: BW.
# disaggregator.temporal: INFO     ... creating state-specific load-profiles
# disaggregator.temporal: INFO     ... assigning load-profiles
# disaggregator.temporal: INFO     Working on state: BY.
# disaggregator.temporal: INFO     ... creating state-specific load-profiles
# disaggregator.temporal: INFO     ... assigning load-profiles
# disaggregator.temporal: INFO     Working on state: SL.
# disaggregator.temporal: INFO     ... creating state-specific load-profiles
# disaggregator.temporal: INFO     ... assigning load-profiles
# disaggregator.temporal: INFO     Working on state: BE.
# disaggregator.temporal: INFO     ... creating state-specific load-profiles
# disaggregator.temporal: INFO     ... assigning load-profiles
# disaggregator.temporal: INFO     Working on state: BB.
# disaggregator.temporal: INFO     ... creating state-specific load-profiles
# disaggregator.temporal: INFO     ... assigning load-profiles
# disaggregator.temporal: INFO     Working on state: MV.
# disaggregator.temporal: INFO     ... creating state-specific load-profiles
# disaggregator.temporal: INFO     ... assigning load-profiles
# disaggregator.temporal: INFO     Working on state: SN.
# disaggregator.temporal: INFO     ... creating state-specific load-profiles
# disaggregator.temporal: INFO     ... assigning load-profiles
# disaggregator.temporal: INFO     Working on state: ST.
# disaggregator.temporal: INFO     ... creating state-specific load-profiles
# disaggregator.temporal: INFO     ... assigning load-profiles
# disaggregator.temporal: INFO     Working on state: TH.
# disaggregator.temporal: INFO     ... creating state-specific load-profiles
# disaggregator.temporal: INFO     ... assigning load-profiles

# %%
df_elec_temp_slp.head()
# Out:
#                         DEF01     DEF02     DEF03     DEF04     DEF05  \
# 2016-01-01 00:00:00  2.521633  7.226888  6.345100  2.323727  3.899931
# 2016-01-01 00:15:00  3.014247  8.638699  7.584649  2.777679  4.661802
# 2016-01-01 00:30:00  2.793776  8.006839  7.029886  2.574512  4.320825
# 2016-01-01 00:45:00  2.583640  7.404599  6.501127  2.380868  3.995831
# 2016-01-01 01:00:00  2.380394  6.822104  5.989705  2.193573  3.681492
#
#                         DEF06     DEF07     DEF08      DEF09     DEF0A  ...  \
# 2016-01-01 00:00:00  5.662803  4.810766  5.855720   9.021537  3.764580  ...
# 2016-01-01 00:15:00  6.769060  5.750575  6.999666  10.783941  4.500010  ...
# 2016-01-01 00:30:00  6.273952  5.329961  6.487690   9.995172  4.170867  ...
# 2016-01-01 00:45:00  5.802052  4.929064  5.999713   9.243378  3.857152  ...
# 2016-01-01 01:00:00  5.345624  4.541311  5.527736   8.516232  3.553723  ...
#
#                         DEG0F     DEG0G     DEG0H     DEG0I     DEG0J  \
# 2016-01-01 00:00:00  3.216371  2.409696  1.667102  3.206336  2.528733
# 2016-01-01 00:15:00  3.844706  2.880443  1.992780  3.832711  3.022734
# 2016-01-01 00:30:00  3.563493  2.669759  1.847022  3.552376  2.801643
# 2016-01-01 00:45:00  3.295462  2.468951  1.708097  3.285181  2.590915
# 2016-01-01 01:00:00  3.036219  2.274727  1.573727  3.026747  2.387096
#
#                         DEG0K     DEG0L     DEG0M     DEG0N     DEG0P
# 2016-01-01 00:00:00  2.433873  2.966796  2.709474  1.244561  3.686856
# 2016-01-01 00:15:00  2.909343  3.546375  3.238784  1.487693  4.407102
# 2016-01-01 00:30:00  2.696546  3.286983  3.001890  1.378879  4.084754
# 2016-01-01 00:45:00  2.493723  3.039750  2.776101  1.275165  3.777516
# 2016-01-01 01:00:00  2.297550  2.800623  2.557714  1.174852  3.480351
#
# [5 rows x 401 columns]

# %% [markdown]
# ... and can then be plotted directly:

# %%
fig, ax = plot.heatmap_timeseries(df_elec_temp_slp.resample('H').sum()['DE300'], clabel='[MWh]')

# %% [markdown]
# # Gas by 'Standard Load Profiles' (SLP, all years)
# update Dec 2020

# %% [markdown]
# Use ``disagg_temporal_gas_households()`` to get hourly gas demand of household per region in **MWh**. Function uses spatial function ``disagg_households_gas()``, which distinguishes between gas demand for heating, cooking and warm water. However, demands are summed up for SLP.
# Demands are then split between demand for _single family houses (EFH)_ and _multi family houses (MFH)_ with the help of ``data.percentage_EFH_MFH()``, which calculates the percentages of EFH and MFH per NUTS-3 based on the available living spaces.

# %%
# use function disagg_daily_gas_slp_households similar as for CTS to create gas SLP for all years
# specify year either through config file (restart kernel after) or specify directly in function
df_households_gas = temporal.disagg_temporal_gas_households(use_nuts3code=True, year=2017)
# Out:
# disaggregator.data: INFO     Dropping old NUTS-v2013 regions.
# disaggregator.temporal: INFO     Working on state: SH.
# disaggregator.spatial: INFO     Calculating regional gas demands top-down.
# disaggregator.temporal: INFO     ... creating state-specific load-profiles
# disaggregator.temporal: INFO     Working on state: HH.
# disaggregator.spatial: INFO     Calculating regional gas demands top-down.
# disaggregator.temporal: INFO     ... creating state-specific load-profiles
# disaggregator.temporal: INFO     Working on state: NI.
# disaggregator.spatial: INFO     Calculating regional gas demands top-down.
# disaggregator.temporal: INFO     ... creating state-specific load-profiles
# disaggregator.temporal: INFO     Working on state: HB.
# disaggregator.spatial: INFO     Calculating regional gas demands top-down.
# disaggregator.temporal: INFO     ... creating state-specific load-profiles
# disaggregator.temporal: INFO     Working on state: NW.
# disaggregator.spatial: INFO     Calculating regional gas demands top-down.
# disaggregator.temporal: INFO     ... creating state-specific load-profiles
# disaggregator.temporal: INFO     Working on state: HE.
# disaggregator.spatial: INFO     Calculating regional gas demands top-down.
# disaggregator.temporal: INFO     ... creating state-specific load-profiles
# disaggregator.temporal: INFO     Working on state: RP.
# disaggregator.spatial: INFO     Calculating regional gas demands top-down.
# disaggregator.temporal: INFO     ... creating state-specific load-profiles
# disaggregator.temporal: INFO     Working on state: BW.
# disaggregator.spatial: INFO     Calculating regional gas demands top-down.
# disaggregator.temporal: INFO     ... creating state-specific load-profiles
# disaggregator.temporal: INFO     Working on state: BY.
# disaggregator.spatial: INFO     Calculating regional gas demands top-down.
# disaggregator.temporal: INFO     ... creating state-specific load-profiles
# disaggregator.temporal: INFO     Working on state: SL.
# disaggregator.spatial: INFO     Calculating regional gas demands top-down.
# disaggregator.temporal: INFO     ... creating state-specific load-profiles
# disaggregator.temporal: INFO     Working on state: BE.
# disaggregator.spatial: INFO     Calculating regional gas demands top-down.
# disaggregator.temporal: INFO     ... creating state-specific load-profiles
# disaggregator.temporal: INFO     Working on state: BB.
# disaggregator.spatial: INFO     Calculating regional gas demands top-down.
# disaggregator.temporal: INFO     ... creating state-specific load-profiles
# disaggregator.temporal: INFO     Working on state: MV.
# disaggregator.spatial: INFO     Calculating regional gas demands top-down.
# disaggregator.temporal: INFO     ... creating state-specific load-profiles
# disaggregator.temporal: INFO     Working on state: SN.
# disaggregator.spatial: INFO     Calculating regional gas demands top-down.
# disaggregator.temporal: INFO     ... creating state-specific load-profiles
# disaggregator.temporal: INFO     Working on state: ST.
# disaggregator.spatial: INFO     Calculating regional gas demands top-down.
# disaggregator.temporal: INFO     ... creating state-specific load-profiles
# disaggregator.temporal: INFO     Working on state: TH.
# disaggregator.spatial: INFO     Calculating regional gas demands top-down.
# disaggregator.temporal: INFO     ... creating state-specific load-profiles

# %%
df_households_gas.head()
# Out:
# ags_lk                    DE111       DE112       DE113       DE114  \
# 2017-01-01 00:00:00  247.970136  171.311272  281.113367  125.872131
# 2017-01-01 01:00:00  255.266509  175.778068  278.463519  129.143872
# 2017-01-01 02:00:00  259.485919  179.241110  278.304506  131.698171
# 2017-01-01 03:00:00  279.067315  191.888683  288.205123  140.975311
# 2017-01-01 04:00:00  335.122964  228.258824  331.764758  167.656364
#
# ags_lk                    DE115       DE116      DE117       DE118      DE119  \
# 2017-01-01 00:00:00  266.244686  208.347180  62.342533  165.684524  53.524665
# 2017-01-01 01:00:00  273.282283  213.908530  64.065576  169.735732  54.840805
# 2017-01-01 02:00:00  278.573211  217.997188  65.232710  173.341775  55.998686
# 2017-01-01 03:00:00  298.375998  233.576720  69.984907  185.161526  59.828412
# 2017-01-01 04:00:00  355.292939  278.338809  83.620825  219.233280  70.865690
#
# ags_lk                    DE11A  ...      DEG0F      DEG0G      DEG0H  \
# 2017-01-01 00:00:00   94.085525  ...  49.787493  47.218522  27.872201
# 2017-01-01 01:00:00   96.421562  ...  51.091460  48.366397  28.600643
# 2017-01-01 02:00:00   98.435370  ...  52.092371  49.400465  29.162455
# 2017-01-01 03:00:00  105.201809  ...  55.776980  52.758734  31.222809
# 2017-01-01 04:00:00  124.695593  ...  66.370898  62.441432  37.147172
#
# ags_lk                   DEG0I      DEG0J      DEG0K      DEG0L      DEG0M  \
# 2017-01-01 00:00:00  52.347202  37.868065  38.051811  49.844194  38.265077
# 2017-01-01 01:00:00  53.714487  38.810643  39.008105  51.138051  39.291432
# 2017-01-01 02:00:00  54.770412  39.618921  39.811575  52.151174  40.037623
# 2017-01-01 03:00:00  58.638746  42.345931  42.565839  55.822194  42.906565
# 2017-01-01 04:00:00  69.762039  50.201574  50.497132  66.380573  51.147924
#
# ags_lk                   DEG0N      DEG0P
# 2017-01-01 00:00:00  21.422530  65.052095
# 2017-01-01 01:00:00  22.033458  66.648314
# 2017-01-01 02:00:00  22.416521  68.058786
# 2017-01-01 03:00:00  24.078406  72.708132
# 2017-01-01 04:00:00  28.841430  86.108619
#
# [5 rows x 401 columns]

# %% [markdown]
# plot df directly...

# %%
fig, ax = plot.heatmap_timeseries(df_households_gas.sum(axis=1)/1e3, clabel='[GWh]')
ax[0, 0].set_title('Gas Load Private Households Germany')
# Out:
# Text(0.5, 1.0, 'Gas Load Private Households Germany')

# %% [markdown]
# ### older version below

# %% [markdown]
# normalized gas SLP for _single family houses_ (EFH) and _multi family houses (MFH)_ have been uploaded into the database untill 2016 as well. which could be used with ``temporal.disagg_temporal(df_spat, df_temp)`` and ``data.transpose_spatiotemporal()`` to perform the same disaggregation.

# %%
df_temp_EFH = data.standard_load_profile_gas(typ='EFH') # type='MFH'
df_temp_EFH
# Out:
# disaggregator.data: INFO     Merging old Göttingen+Osterode to new NUTS-v2016 region.
# nuts3                   DE111     DE112     DE113     DE114     DE115  \
# 2015-01-01 00:00:00  0.000175  0.000172  0.000181  0.000177  0.000180
# 2015-01-01 01:00:00  0.000178  0.000174  0.000184  0.000180  0.000183
# 2015-01-01 02:00:00  0.000183  0.000177  0.000187  0.000184  0.000187
# 2015-01-01 03:00:00  0.000193  0.000186  0.000197  0.000194  0.000197
# 2015-01-01 04:00:00  0.000224  0.000208  0.000222  0.000221  0.000222
# ...                       ...       ...       ...       ...       ...
# 2015-12-31 19:00:00  0.000260  0.000235  0.000273  0.000242  0.000271
# 2015-12-31 20:00:00  0.000250  0.000228  0.000263  0.000234  0.000262
# 2015-12-31 21:00:00  0.000221  0.000204  0.000235  0.000208  0.000234
# 2015-12-31 22:00:00  0.000158  0.000149  0.000172  0.000151  0.000171
# 2015-12-31 23:00:00  0.000126  0.000119  0.000137  0.000120  0.000136
#
# nuts3                   DE116     DE117     DE118     DE119     DE11A  ...  \
# 2015-01-01 00:00:00  0.000181  0.000153  0.000157  0.000155  0.000150  ...
# 2015-01-01 01:00:00  0.000184  0.000158  0.000162  0.000160  0.000155  ...
# 2015-01-01 02:00:00  0.000187  0.000161  0.000164  0.000162  0.000157  ...
# 2015-01-01 03:00:00  0.000197  0.000174  0.000177  0.000175  0.000169  ...
# 2015-01-01 04:00:00  0.000222  0.000207  0.000203  0.000201  0.000194  ...
# ...                       ...       ...       ...       ...       ...  ...
# 2015-12-31 19:00:00  0.000260  0.000275  0.000275  0.000260  0.000255  ...
# 2015-12-31 20:00:00  0.000251  0.000264  0.000266  0.000252  0.000247  ...
# 2015-12-31 21:00:00  0.000225  0.000235  0.000238  0.000226  0.000221  ...
# 2015-12-31 22:00:00  0.000164  0.000169  0.000175  0.000165  0.000162  ...
# 2015-12-31 23:00:00  0.000130  0.000135  0.000139  0.000131  0.000129  ...
#
# nuts3                   DEG0G     DEG0H     DEG0I     DEG0J     DEG0K  \
# 2015-01-01 00:00:00  0.000136  0.000130  0.000134  0.000134  0.000133
# 2015-01-01 01:00:00  0.000140  0.000132  0.000138  0.000138  0.000137
# 2015-01-01 02:00:00  0.000143  0.000135  0.000141  0.000141  0.000140
# 2015-01-01 03:00:00  0.000154  0.000143  0.000152  0.000151  0.000150
# 2015-01-01 04:00:00  0.000179  0.000164  0.000180  0.000178  0.000179
# ...                       ...       ...       ...       ...       ...
# 2015-12-31 19:00:00  0.000259  0.000229  0.000261  0.000253  0.000261
# 2015-12-31 20:00:00  0.000250  0.000220  0.000250  0.000244  0.000250
# 2015-12-31 21:00:00  0.000223  0.000196  0.000223  0.000217  0.000222
# 2015-12-31 22:00:00  0.000163  0.000151  0.000161  0.000169  0.000160
# 2015-12-31 23:00:00  0.000130  0.000129  0.000128  0.000145  0.000128
#
# nuts3                   DEG0L     DEG0M     DEG0N     DEG0P     DE91C
# 2015-01-01 00:00:00  0.000131  0.000135  0.000129  0.000131  0.000125
# 2015-01-01 01:00:00  0.000135  0.000139  0.000133  0.000135  0.000128
# 2015-01-01 02:00:00  0.000138  0.000142  0.000135  0.000137  0.000131
# 2015-01-01 03:00:00  0.000149  0.000153  0.000145  0.000148  0.000141
# 2015-01-01 04:00:00  0.000177  0.000182  0.000171  0.000172  0.000167
# ...                       ...       ...       ...       ...       ...
# 2015-12-31 19:00:00  0.000264  0.000270  0.000239  0.000255  0.000239
# 2015-12-31 20:00:00  0.000253  0.000260  0.000231  0.000246  0.000230
# 2015-12-31 21:00:00  0.000226  0.000231  0.000205  0.000219  0.000205
# 2015-12-31 22:00:00  0.000174  0.000166  0.000160  0.000172  0.000148
# 2015-12-31 23:00:00  0.000149  0.000133  0.000137  0.000147  0.000118
#
# [8760 rows x 401 columns]

# %% [markdown]
# This dataframe has the NUTS-3-regions in columns and the timesteps in rows. Though being intuitive that way, the function ` temporal.disagg_temporal(df_spat, df_temp)` requires us to provide the temporal dataset _NUTS-3-index'ed_ (i.e. with timesteps in columns) for compatibility reasons. To achieve that, we use the function `data.transpose_spatiotemporal()`

# %%
df_temp_EFH = data.transpose_spatiotemporal(df_temp_EFH)
df_temp_MFH = data.transpose_spatiotemporal(df_temp_MFH)
df_temp_EFH
# Out:
#            0         1         2         3         4         5         6     \
# nuts3
# DE111  0.000175  0.000178  0.000183  0.000193  0.000224  0.000290  0.000369
# DE112  0.000172  0.000174  0.000177  0.000186  0.000208  0.000267  0.000358
# DE113  0.000181  0.000184  0.000187  0.000197  0.000222  0.000286  0.000378
# DE114  0.000177  0.000180  0.000184  0.000194  0.000221  0.000284  0.000371
# DE115  0.000180  0.000183  0.000187  0.000197  0.000222  0.000285  0.000377
# ...         ...       ...       ...       ...       ...       ...       ...
# 3      231.226693  156.922695  227.043618  117.579106  240.922749  195.765590
# 4      278.556198  181.054589  264.950003  138.233133  281.091092  228.570652
# ...           ...         ...         ...         ...         ...         ...
# 8755   314.090461  203.074292  317.413566  150.167164  335.982110  262.806997
# 8756   306.463190  197.950235  309.299142  146.187917  327.377730  256.125845
# 8757   279.453315  180.485269  281.524511  132.771521  297.949142  233.200682
# 8758   237.972461  146.591400  230.479847  108.517966  243.781079  191.273030
# 8759   175.916827  109.749918  172.512153   81.296343  182.523920  143.029587
#
# nuts3      DE117       DE118      DE119       DE11A  ...      DEG0F  \
# 0      46.664946  125.313498  40.966770   71.888898  ...  37.601944
# 1      49.481993  132.482112  43.324687   76.071898  ...  38.587374
# 2      50.324357  134.735586  44.064635   77.380612  ...  39.355704
# 3      54.438691  146.899689  48.051481   84.408961  ...  42.037045
# 4      66.599228  174.521929  57.113042  100.409284  ...  49.457693
# ...          ...         ...        ...         ...  ...        ...
# 8755   83.355251  224.816658  70.565079  125.910215  ...  66.191563
# 8756   81.185021  218.918489  68.720740  122.636583  ...  64.034881
# 8757   73.812184  199.059705  62.503687  111.583484  ...  58.202722
# 8758   61.460372  159.272448  50.085301   89.598399  ...  49.653045
# 8759   45.872932  120.259720  37.785258   67.515639  ...  38.205939
#
# nuts3      DEG0G      DEG0H      DEG0I      DEG0J      DEG0K      DEG0L  \
# 0      31.987246  22.623693  39.149205  27.469076  27.904335  36.820917
# 1      33.730421  23.153930  41.372317  28.951076  29.422889  38.897128
# 2      34.361495  23.643103  42.095773  29.542102  29.946436  39.579315
# 3      37.298965  25.313782  45.519867  31.960713  32.374033  42.796880
# 4      44.664247  29.969928  55.495775  38.607296  39.378124  52.155819
# ...          ...        ...        ...        ...        ...        ...
# 8755   61.206344  40.016742  75.331808  52.080561  54.080492  72.791854
# 8756   59.546183  38.661304  73.244038  50.368402  52.523265  70.319502
# 8757   54.008123  35.154707  66.408670  45.661581  47.536601  63.918529
# 8758   43.306549  30.006721  54.412310  38.560801  38.539324  54.468427
# 8759   32.764229  23.077802  40.905329  30.023557  29.110732  41.964339
#
# nuts3      DEG0M      DEG0N      DEG0P
# 0      28.991814  14.353573  43.707776
# 1      30.684640  15.257009  46.112055
# 2      31.214834  15.566148  46.977266
# 3      33.759688  16.888222  51.002784
# 4      41.222296  20.578529  61.118043
# ...          ...        ...        ...
# 8755   56.915518  26.838796  85.493281
# 8756   55.378941  25.978411  82.748003
# 8757   50.270176  23.722653  75.045812
# 8758   41.475497  20.601348  63.098041
# 8759   31.083379  15.526047  49.484715
#
# [8760 rows x 401 columns]

# %% [markdown]
# Instead of selecting one specific region, this time we choose to sum it up for the entire country:

# %%
ser_gas = df_gas_st.sum(axis=1)

# %% [markdown]
# Now we can plot this one again as well:

# %%
fig, ax = plot.heatmap_timeseries(ser_gas/1e3, clabel='[GWh]')
ax[0, 0].set_title('Gas Load Private Households Germany')
# Out:
# Text(0.5, 1, 'Gas Load Private Households Germany')
