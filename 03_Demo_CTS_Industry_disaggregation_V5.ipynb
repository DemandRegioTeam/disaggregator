# %%
import pandas as pd
import numpy as np
from disaggregator import config, data, spatial, temporal, plot
import matplotlib.pyplot as plt

# %% [markdown]
# # General Settings and functions

# %% [markdown]
# ## Base year
# - By setting the ``base year`` in the ``config.yaml``, you define the year on which the spatial and temporal functions operate
# - some functions are not affected, e. g. ``generate_specific_consumption_per_branch()`` because it makes use of particular publications from these years

# %% [markdown]
# ## Region Codes
# - The function ``config.dict_region_code()`` returns a dictionary with conversions of different kinds of region denotation, if ``raw = False``
# - the dictionary can convert between the following designations ``ags_lk``, ``id_ags``, ``id_ags_lk``, ``id_nuts3``, ``id_t_nuts3_lk``, ``name``, ``natcode_nuts3``

# %%
config.dict_region_code(raw=True)
# Out:
#      ags_lk    id_ags  id_ags_lk  id_nuts3  id_t_nuts3_lk  \
# idx
# 0      3152   3152000         21  27600021             21
# 1      3156   3156000         25  27600025             25
# 2      1001   1001000          1  27600001              1
# 3      1002   1002000          2  27600002              2
# 4      1003   1003000          3  27600003              3
# ..      ...       ...        ...       ...            ...
# 398   16073  16073000        409  27600409            391
# 399   16074  16074000        410  27600410            392
# 400   16075  16075000        411  27600411            393
# 401   16076  16076000        412  27600412            394
# 402   16077  16077000        413  27600413            395
#
#                             name natcode_nuts3
# idx
# 0                      Göttingen         DE915
# 1               Osterode am Harz         DE919
# 2    Flensburg, Kreisfreie Stadt         DEF01
# 3         Kiel, Kreisfreie Stadt         DEF02
# 4       Lübeck, Kreisfreie Stadt         DEF03
# ..                           ...           ...
# 398          Saalfeld-Rudolstadt         DEG0I
# 399         Saale-Holzland-Kreis         DEG0J
# 400             Saale-Orla-Kreis         DEG0K
# 401                        Greiz         DEG0L
# 402             Altenburger Land         DEG0M
#
# [403 rows x 7 columns]

# %% [markdown]
# # Spatial Functions

# %% [markdown]
# ### Function ``disagg_CTS_industry()``
# - returns a DataFrame with absolute gas or electricity consumption per branch and district for the sectors CTS or industry in **MWh** for the ``base year`` (see ``config.yaml``)
# - uses files "../data_in/regional/specific_`source`_consumption.csv", with ``source`` being in [``power``, ``gas``], if file does not exist, the function ``generate_specific_consumption_per_branch_and_district()`` is called

# %%
df_abs_econ_dis_branch_CTS = spatial.disagg_CTS_industry(source = 'power', sector = 'CTS', use_nuts3code=True) # also possible: source='gas', sector ='industry'
# get dictionary for renaming columns
dic = config.dict_region_code(keys='natcode_nuts3', values='name')
df_abs_econ_dis_branch_CTS.rename(columns=dic).head()
# Out:
#     Flensburg, Kreisfreie Stadt  Kiel, Kreisfreie Stadt  \
# WZ
# 1                    278.613484             1243.044776
# 2                      0.000000               49.822825
# 3                      0.000000                0.000000
# 36                     0.000000            16917.988254
# 37                 13045.394931             1593.907460
#
#     Lübeck, Kreisfreie Stadt  Neumünster, Kreisfreie Stadt  Dithmarschen  \
# WZ
# 1                1928.862583                   3664.838908  31504.755524
# 2                  54.430913                      0.000000     18.696504
# 3                1081.912997                      0.000000   2615.861858
# 36                  0.000000                      0.000000      0.000000
# 37                  0.000000                   8210.603187   2254.487844
#
#     Herzogtum Lauenburg  Nordfriesland   Ostholstein     Pinneberg  \
# WZ
# 1          14012.017687   25482.417904  18752.830669  42542.135861
# 2            971.732113       8.064970     84.670308     67.871916
# 3            104.510318    4613.429094   1046.344743    356.329406
# 36          8190.370493    3498.114316   5837.385789  10491.334771
# 37         19668.618823    8526.395617   2432.355116  11636.024520
#
#             Plön  ...      Sömmerda  Hildburghausen    Ilm-Kreis  \
# WZ                ...
# 1   14745.082858  ...  24046.486870    14151.605925  9935.120169
# 2     435.447300  ...     19.956501      290.439081   275.892430
# 3     713.416870  ...      0.000000       36.658340    93.914547
# 36      0.000000  ...   8655.968414     2872.877928  7359.990418
# 37   3606.288363  ...   3606.818157        0.000000  3066.802673
#
#     Weimarer Land     Sonneberg  Saalfeld-Rudolstadt  Saale-Holzland-Kreis  \
# WZ
# 1    18474.217185   3879.156973         14980.832729          27882.780229
# 2      107.256266   1264.816441           229.819408             24.705839
# 3        0.000000      0.000000           441.283998            147.408823
# 36    4905.756829  40296.263099         23418.305060           2620.079185
# 37    6000.056175   2870.711796          2684.235657           1489.556858
#
#     Saale-Orla-Kreis         Greiz  Altenburger Land
# WZ
# 1       29425.870296  20107.112173      15880.968601
# 2         532.213367    199.857928          0.000000
# 3         332.927873      0.000000          0.000000
# 36       6435.012265  15715.617801      14532.732944
# 37       2681.377515      0.000000       4722.459548
#
# [5 rows x 401 columns]

# %%
plot.choropleth_map(df_abs_econ_dis_branch_CTS.sum()/1000, relative = False, unit = 'GWh')
# Out:
# (<Figure size 302.4x475.2 with 2 Axes>,
#  array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000004DB9F9EA90>]],
#        dtype=object))

# %% [markdown]
# ### Function ``generate_specific_consumption_per_branch_and_district()``
# - Returns specific power and gas consumption per branch and district.
# - saves result in ``../data_in/regional/specific_power_consumption.csv`` and ``../data_in/specific_gas_consumption.csv``
# - Takes number of iterations as arguments, 8 is recommended. Look at docstring for clarification.

# %%
df_spec_econ_district, df_spec_gcon_district = data.generate_specific_consumption_per_branch_and_district(8,8)

# %%
df_spec_econ_district.head()
# Out:
#         1001        1002        1003        1004         1051        1053   \
# 1   21.431806   21.431806   21.431806   21.431806    21.431806   21.431806
# 2    6.047879    6.047879    6.047879    6.047879     6.047879    6.047879
# 3   47.561125   47.561125   47.561125   47.561125    47.561125   47.561125
# 5  167.180743  238.494784  138.232790  144.713079  1001.644188  155.656725
# 6   76.647782  109.343313   63.375940   66.346975   459.226368   71.364336
#
#         1054        1055        1056        1057   ...       16068  \
# 1   21.431806   21.431806   21.431806   21.431806  ...   21.431806
# 2    6.047879    6.047879    6.047879    6.047879  ...    6.047879
# 3   47.561125   47.561125   47.561125   47.561125  ...   47.561125
# 5  400.074771  252.001533  235.649094  400.074771  ...  400.074771
# 6  183.423302  115.535786  108.038642  183.423302  ...  183.423302
#
#         16069       16070       16071       16072       16073       16074  \
# 1   21.431806   21.431806   21.431806   21.431806   21.431806   21.431806
# 2    6.047879    6.047879    6.047879    6.047879    6.047879    6.047879
# 3   47.561125   47.561125   47.561125   47.561125   47.561125   47.561125
# 5  299.714927  400.074771  400.074771  400.074771  898.696747  225.113494
# 6  137.411068  183.423302  183.423302  183.423302  412.027792  103.208358
#
#         16075       16076       16077
# 1   21.431806   21.431806   21.431806
# 2    6.047879    6.047879    6.047879
# 3   47.561125   47.561125   47.561125
# 5  458.380276  223.771238  400.074771
# 6  210.154776  102.592971  183.423302
#
# [5 rows x 401 columns]

# %%
df_spec_gcon_district.head()
# Out:
#         1001        1002        1003        1004         1051       1053   \
# 1    6.736410    6.736410    6.736410    6.736410     6.736410   6.736410
# 2    0.008478    0.008478    0.008478    0.008478     0.008478   0.008478
# 3    0.007103    0.007103    0.007103    0.007103     0.007103   0.007103
# 5   11.154951   11.154951   11.154951   11.154951    45.327550  11.154951
# 6  428.334392  198.598526  221.583619  270.955301  2294.159525  96.754835
#
#         1054        1055        1056        1057   ...       16068  \
# 1    6.736410    6.736410    6.736410    6.736410  ...    6.736410
# 2    0.008478    0.008478    0.008478    0.008478  ...    0.008478
# 3    0.007103    0.007103    0.007103    0.007103  ...    0.007103
# 5   14.122494   14.122494   17.267132   14.122494  ...   11.154951
# 6  714.780613  714.780613  873.939905  714.780613  ...  268.890689
#
#         16069       16070       16071        16072       16073       16074  \
# 1    6.736410    6.736410    6.736410     6.736410    6.736410    6.736410
# 2    0.008478    0.008478    0.008478     0.008478    0.008478    0.008478
# 3    0.007103    0.007103    0.007103     0.007103    0.007103    0.007103
# 5   11.154951   11.465445   11.154951    21.240471   13.777111   11.154951
# 6  253.061313  580.299626  285.562813  1075.042201  697.299797  344.549566
#
#         16075       16076       16077
# 1    6.736410    6.736410    6.736410
# 2    0.008478    0.008478    0.008478
# 3    0.007103    0.007103    0.007103
# 5   11.154951   11.154951   11.154951
# 6  399.374712  340.860342  323.162319
#
# [5 rows x 401 columns]

# %% [markdown]
# ### Function ``generate_specific_consumption_per_branch()``
# - this function is the basis for ``generate_specific_consumption_per_branch_and_district()``
# - it returns number of employees, as well as absolute and specific power and gas consumption per industry and CTS branch (WZ08) in Germany for the year 2015
# - the values are based on the publication [Umweltökonomische Gesamtrechnung, 2017](https://www.destatis.de/DE/Themen/Gesellschaft-Umwelt/Umwelt/Publikationen/Umweltnutzung-Wirtschaft/umweltnutzung-und-wirtschaft-energie-pdf-5850014.html) for 2015, which is also available from the DemandRegio database (table_id = 38) with some industry branches (WZ) being grouped together and with ET = 12 for gas and ET = 18 for electricity)

# %%
df_spez_econ, df_spez_gcon, df_abs_con, df_emp = data.generate_specific_consumption_per_branch()

# %%
## specific electricity consumption 
df_spez_econ.head()
## specific gas consumption 
df_spez_gcon.head()
# Out:
#      spez. GV
# 1    6.736410
# 2    0.008478
# 3    0.007103
# 5   58.078803
# 6  778.569888

# %%
## employees by branch and district
df_emp.head()
## absolute consumption as in "Umweltökonomischer Gesamtrechnung" for the year 2015, in Database dimension='spatial', table_id=38,
df_abs_con.head()
# Out:
#             value WZ  ET
# idx
# 19   1.547398e+06  1  12
# 23   4.923029e+06  1  18
# 30   1.657324e+02  2  12
# 33   1.182279e+05  2  18
# 39   1.765487e+01  3  12

# %% [markdown]
# ### Function ``employees_per_branch_district()``
# - Read, transform and return the number of employees per NUTS-3 area and branch for a given year

# %%
df_employees = data.employees_per_branch_district(year = 2016)
df_employees.head()
# Out:
# ags  1001       1002       1003        1004         1051        1053   \
# WZ
# 1     12.0  57.000000  89.000000  165.048837  1555.000000  635.000000
# 2      0.0   8.829132   7.000000    0.000000     3.074138  161.000000
# 3      0.0   0.000000  23.675835    0.000000    50.000000    2.677613
# 5      0.0   0.000000   0.000000    0.000000     0.000000    0.000000
# 6      0.0   0.000000   0.000000    0.000000   144.633221    0.000000
#
# ags        1054   1055         1056        1057   ...        16068  \
# WZ                                                ...
# 1    1193.935134  930.0  1931.000000  733.365613  ...  1066.000000
# 2       1.278226   15.0    11.418690   69.563809  ...     4.016232
# 3      98.056052   29.0     7.116517   14.772749  ...     0.000000
# 5       0.000000    0.0     0.000000    0.000000  ...     0.000000
# 6       0.000000    0.0     0.000000    0.000000  ...     0.000000
#
# ags       16069       16070  16071       16072       16073        16074  \
# WZ
# 1    641.000000  459.000000  805.0  178.000000  687.000000  1310.000000
# 2     45.000000   48.000000   19.0  213.774999   38.000000     5.000000
# 3      0.231578    2.571744    0.0    0.000000    9.644818     3.059019
# 5      0.000000  103.885849    0.0    0.000000    0.000000     0.000000
# 6      0.000000    0.000000    0.0    0.000000    0.000000     0.000000
#
# ags        16075  16076  16077
# WZ
# 1    1301.977198  923.0  711.0
# 2     116.121597   33.0    0.0
# 3       6.866084    0.0    0.0
# 5       0.000000    0.0    0.0
# 6       0.000000    0.0    0.0
#
# [5 rows x 401 columns]

# %% [markdown]
# ### Function ``energy_balance_values()``
# - Read, transform and return information from german federal energy balances (LAK) for each federal state for the base year
# - available at the DemandRegio Database, table_id: 59

# %%
df_LAK = data.energy_balance_values(internal_id = [52,29])

# %% [markdown]
# # Temporal Functions

# %% [markdown]
# ### Function disagg_temporal_power_CTS()
# - Disagreggate spatial data of CTS' power demand temporally in **MWh**
# - returns DataFrame with districts as columns and timesteps as rows
# - if ``detailed = True``, returns DataFrame with multiindex in columns with ``level=0`` for districts and ``level=1`` for branches, timesteps as rows
# - Uses temporal and spatial functions `disagg_CTS('power')` , `CTS_power_slp_generator` and information from `config.py`
# - if ``detailed = True`` it takes about 15 minutes to run on machine with 16GB RAM

# %%
df_CTS = temporal.disagg_temporal_power_CTS(detailed = False, use_nuts3code=True)
# Out:
# disaggregator.temporal: INFO     Working on state: SH.
# disaggregator.temporal: INFO     ... creating state-specific load-profiles
# disaggregator.temporal: INFO     ... assigning load-profiles to WZs
# disaggregator.temporal: INFO     Working on state: HH.
# disaggregator.temporal: INFO     ... creating state-specific load-profiles
# disaggregator.temporal: INFO     ... assigning load-profiles to WZs
# disaggregator.temporal: INFO     Working on state: NI.
# disaggregator.temporal: INFO     ... creating state-specific load-profiles
# disaggregator.temporal: INFO     ... assigning load-profiles to WZs
# disaggregator.temporal: INFO     Working on state: HB.
# disaggregator.temporal: INFO     ... creating state-specific load-profiles
# disaggregator.temporal: INFO     ... assigning load-profiles to WZs
# disaggregator.temporal: INFO     Working on state: NW.
# disaggregator.temporal: INFO     ... creating state-specific load-profiles
# disaggregator.temporal: INFO     ... assigning load-profiles to WZs
# disaggregator.temporal: INFO     Working on state: HE.
# disaggregator.temporal: INFO     ... creating state-specific load-profiles
# disaggregator.temporal: INFO     ... assigning load-profiles to WZs
# disaggregator.temporal: INFO     Working on state: RP.
# disaggregator.temporal: INFO     ... creating state-specific load-profiles
# disaggregator.temporal: INFO     ... assigning load-profiles to WZs
# disaggregator.temporal: INFO     Working on state: BW.
# disaggregator.temporal: INFO     ... creating state-specific load-profiles
# disaggregator.temporal: INFO     ... assigning load-profiles to WZs
# disaggregator.temporal: INFO     Working on state: BY.
# disaggregator.temporal: INFO     ... creating state-specific load-profiles
# disaggregator.temporal: INFO     ... assigning load-profiles to WZs
# disaggregator.temporal: INFO     Working on state: SL.
# disaggregator.temporal: INFO     ... creating state-specific load-profiles
# disaggregator.temporal: INFO     ... assigning load-profiles to WZs
# disaggregator.temporal: INFO     Working on state: BE.
# disaggregator.temporal: INFO     ... creating state-specific load-profiles
# disaggregator.temporal: INFO     ... assigning load-profiles to WZs
# disaggregator.temporal: INFO     Working on state: BB.
# disaggregator.temporal: INFO     ... creating state-specific load-profiles
# disaggregator.temporal: INFO     ... assigning load-profiles to WZs
# disaggregator.temporal: INFO     Working on state: MV.
# disaggregator.temporal: INFO     ... creating state-specific load-profiles
# disaggregator.temporal: INFO     ... assigning load-profiles to WZs
# disaggregator.temporal: INFO     Working on state: SN.
# disaggregator.temporal: INFO     ... creating state-specific load-profiles
# disaggregator.temporal: INFO     ... assigning load-profiles to WZs
# disaggregator.temporal: INFO     Working on state: ST.
# disaggregator.temporal: INFO     ... creating state-specific load-profiles
# disaggregator.temporal: INFO     ... assigning load-profiles to WZs
# disaggregator.temporal: INFO     Working on state: TH.
# disaggregator.temporal: INFO     ... creating state-specific load-profiles
# disaggregator.temporal: INFO     ... assigning load-profiles to WZs

# %%
df_CTS.head()
# Out:
#                         DEF01     DEF02     DEF03     DEF04     DEF05  \
# 2015-01-01 00:00:00  3.026101  8.141696  5.836679  2.576690  3.592096
# 2015-01-01 00:15:00  3.133197  8.612735  6.064721  2.693237  3.695760
# 2015-01-01 00:30:00  3.058121  8.368633  5.902550  2.624714  3.597708
# 2015-01-01 00:45:00  2.992373  8.161607  5.758232  2.565754  3.512631
# 2015-01-01 01:00:00  2.948346  8.020761  5.654554  2.526372  3.450739
#
#                         DEF06     DEF07     DEF08     DEF09     DEF0A  ...  \
# 2015-01-01 00:00:00  3.556613  5.296562  5.009631  6.295678  2.127877  ...
# 2015-01-01 00:15:00  3.653548  5.512913  5.221665  6.433857  2.202643  ...
# 2015-01-01 00:30:00  3.572257  5.310152  5.037828  6.270684  2.132139  ...
# 2015-01-01 00:45:00  3.502335  5.122099  4.865305  6.130838  2.068793  ...
# 2015-01-01 01:00:00  3.455895  4.968850  4.723135  6.035624  2.019922  ...
#
#                         DEG0D     DEG0E     DEG0F     DEG0G     DEG0H  \
# 2015-01-01 00:00:00  1.804680  1.221589  2.289555  1.890742  1.854995
# 2015-01-01 00:15:00  1.827836  1.235274  2.347462  1.925484  1.908828
# 2015-01-01 00:30:00  1.787666  1.205517  2.295170  1.879225  1.884718
# 2015-01-01 00:45:00  1.754764  1.180335  2.250670  1.840003  1.865834
# 2015-01-01 01:00:00  1.732985  1.162893  2.221546  1.812500  1.857280
#
#                         DEG0I     DEG0J     DEG0K     DEG0L     DEG0M
# 2015-01-01 00:00:00  2.704382  1.999462  1.991427  2.336707  2.131447
# 2015-01-01 00:15:00  2.785547  2.023485  2.015102  2.377832  2.170709
# 2015-01-01 00:30:00  2.725642  1.974935  1.961364  2.329862  2.129014
# 2015-01-01 00:45:00  2.674938  1.934643  1.916207  2.290569  2.094684
# 2015-01-01 01:00:00  2.641283  1.906947  1.883517  2.265971  2.073690
#
# [5 rows x 401 columns]

# %%
# export your data using
df_CTS.to_csv('./data_out/CTS_Power_2015_MWh.csv')

# %% [markdown]
# ### Function disagg_daily_gas_slp()
# - Disagreggate spatial data of CTS' gas demand per hour for a given `state` in MWh
# - returns `DataFrame`with gas demand and column names as *district_SLPname_CTSbranch*
# - Uses temporal and spatial functions `disagg_CTS('gas')` , `gas_slp_weekday_params()`, `h_value()` and information from `config.py`
# - Takes about **5-6 minutes** to run

# %%
df_daily_gas_BE = temporal.disagg_daily_gas_slp('BE')
df_daily_gas_BE.head()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-0869fdad8329> in <module>
# ----> 1 df_daily_gas_BE = temporal.disagg_daily_gas_slp('BE')
#       2 df_daily_gas_BE.head()
#
# E:\PRO_DemandRegio_GitHub\demandregio_github\disaggregator\temporal.py in disagg_daily_gas_slp(state, **kwargs)
#     540     tageswerte = pd.DataFrame(index=calender_df['Date'])
#     541     for slp in gv_lk['SLP'].unique():
# --> 542         h_slp = h_value(slp, list_ags)
#     543         gv_df = (gv_lk.loc[gv_lk['SLP'] == slp].drop(columns=['SLP'])
#     544                       .stack().reset_index())
#
# E:\PRO_DemandRegio_GitHub\demandregio_github\disaggregator\data.py in h_value(slp, districts, normalize)
#     235     pd.DataFrame
#     236     """
# --> 237     temp_df = t_allo()[[x for x in districts]]
#     238     par = gas_load_profile_parameters_dict()
#     239     A = par['A'][slp]
#
# E:\PRO_DemandRegio_GitHub\demandregio_github\disaggregator\data.py in t_allo(**kwargs)
#     194     else:
#     195         periods = 35040
# --> 196     df = ambient_T(year=hist_year, internal_id=2)
#     197     df = (df.assign(date=pd.date_range((str(hist_year) + '-01-01'),
#     198                     periods=periods / 4, freq='H',
#
# E:\PRO_DemandRegio_GitHub\demandregio_github\disaggregator\data.py in ambient_T(**kwargs)
#    1664     """
#    1665     kwargs['check_zero'] = False
# -> 1666     return reshape_spatiotemporal(key='ambient_T', **kwargs)
#    1667
#    1668
#
# E:\PRO_DemandRegio_GitHub\demandregio_github\disaggregator\data.py in reshape_spatiotemporal(freq, key, **kwargs)
#    1709     elif source == 'database':
#    1710         df = (database_get('temporal', table_id=table_id, year=year,
# -> 1711                            internal_id=internal_id, force_update=force_update)
#    1712               .assign(nuts3=lambda x: x.id_region.map(dict_region_code()))
#    1713               .loc[lambda x: (~(x.nuts3.isna()))]
#
# E:\PRO_DemandRegio_GitHub\demandregio_github\disaggregator\data.py in database_get(dimension, table_id, internal_id, year, allow_zero_negative, force_update, **kwargs)
#    1839         return df
#    1840     else:
# -> 1841         return database_raw(query, force_update=force_update)
#    1842
#    1843
#
# E:\PRO_DemandRegio_GitHub\demandregio_github\disaggregator\config.py in database_raw(query, force_update)
#      93                                        'years': literal_converter,
#      94                                        'years_step': literal_converter,
# ---> 95                                        'years_weather': literal_converter})
#      96     else:
#      97         host = get_config()['database_host']
#
# c:\python36\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# --> 685         return _read(filepath_or_buffer, kwds)
#     686
#     687     parser_f.__name__ = name
#
# c:\python36\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     461
#     462     try:
# --> 463         data = parser.read(nrows)
#     464     finally:
#     465         parser.close()
#
# c:\python36\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    1152     def read(self, nrows=None):
#    1153         nrows = _validate_integer("nrows", nrows)
# -> 1154         ret = self._engine.read(nrows)
#    1155
#    1156         # May alter columns / col_dict
#
# c:\python36\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    2057     def read(self, nrows=None):
#    2058         try:
# -> 2059             data = self._reader.read(nrows)
#    2060         except StopIteration:
#    2061             if self._first_chunk:
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_column_data()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers._apply_converter()
#
# E:\PRO_DemandRegio_GitHub\demandregio_github\disaggregator\config.py in literal_converter(val)
#     197 def literal_converter(val):
#     198     try:
# --> 199         return lit_eval(val)
#     200     except (SyntaxError, ValueError):
#     201         return val
#
# c:\python36\lib\ast.py in literal_eval(node_or_string)
#      46     """
#      47     if isinstance(node_or_string, str):
# ---> 48         node_or_string = parse(node_or_string, mode='eval')
#      49     if isinstance(node_or_string, Expression):
#      50         node_or_string = node_or_string.body
#
# KeyboardInterrupt:

# %%
df_daily_gas_BE.sum(axis=1).plot(figsize=(12,6))

# %% [markdown]
# ### Function disagg_temporal_gas_CTS()
# - Disagreggate spatial data of CTS' gas demand per hour for a given `state` in **MWh**
# - Uses temporal and spatial functions like `disagg_daily_gas_slp(state)` and information from `config.py` and `./data_in/Gas Load Profiles/`
# - Takes about **5-8 minutes** to run

# %%
# run function for single state
df_gas_cts_HB = temporal.disagg_temporal_gas_CTS('HB')
df_gas_cts_HB.head()
# Out:
# disaggregator.data: INFO     Dropping old NUTS-v2013 regions.
# disaggregator.data: INFO     Dropping old NUTS-v2013 regions.
# disaggregator.data: INFO     Dropping old NUTS-v2013 regions.
# disaggregator.data: INFO     Dropping old NUTS-v2013 regions.
# disaggregator.data: INFO     Dropping old NUTS-v2013 regions.
# disaggregator.data: INFO     Dropping old NUTS-v2013 regions.
# disaggregator.data: INFO     Dropping old NUTS-v2013 regions.
# disaggregator.data: INFO     Dropping old NUTS-v2013 regions.
# disaggregator.data: INFO     Dropping old NUTS-v2013 regions.
# disaggregator.data: INFO     Dropping old NUTS-v2013 regions.
# ags_lk                     4011       4012
# 2015-01-01 00:00:00  198.542372  36.749675
# 2015-01-01 01:00:00  192.773532  35.707387
# 2015-01-01 02:00:00  186.977272  34.936895
# 2015-01-01 03:00:00  211.148184  39.001893
# 2015-01-01 04:00:00  263.500132  47.411053

# %%
# save your data
df_gas_cts_HB.to_csv('./data_out/CTS_Gas_2015_MWh_HB.csv')

# %%
# plot your data
df_gas_cts_HB.plot(figsize=(12,6), ylim = 0)

# %%
# or run function for all states
for state in config.bl_dict().values():
    df = temporal.disagg_temporal_gas_CTS(state)
    df.to_csv('./data_out/CTS_Gas_2015_MWh_' + state + '.csv')
# Out:
# dict_values(['SH', 'HH', 'NI', 'HB', 'NW', 'HE', 'RP', 'BW', 'BY', 'SL', 'BE', 'BB', 'MV', 'SN', 'ST', 'TH'])

# %% [markdown]
# ### Function disagg_temporal_industry()
# - Disagreggate spatial data of industry *power* and *gas* demand per hour for all districts in **MWh**
# - Uses temporal and spatial functions like `shift_profile_industry()`, `disagg_industry(source)` and information from `config.py`

# %%
df_pow_industry = temporal.disagg_temporal_industry(source='power') # source can be put to 'gas'
df_pow_industry.head()
# Out:
# Working on state: SH.
# Working on state: HH.
# Working on state: NI.
# Working on state: HB.
# Working on state: NW.
# Working on state: HE.
# Working on state: RP.
# Working on state: BW.
# Working on state: BY.
# Working on state: SL.
# Working on state: BE.
# Working on state: BB.
# Working on state: MV.
# Working on state: SN.
# Working on state: ST.
# Working on state: TH.
#                                1001    1002      1003      1004       1051  \
# 2015-01-01 00:00:00+01:00  2.172794  2.6326  4.283729  2.430802  24.178798
# 2015-01-01 00:15:00+01:00  2.172794  2.6326  4.283729  2.430802  24.178798
# 2015-01-01 00:30:00+01:00  2.172794  2.6326  4.283729  2.430802  24.178798
# 2015-01-01 00:45:00+01:00  2.172794  2.6326  4.283729  2.430802  24.178798
# 2015-01-01 01:00:00+01:00  2.172794  2.6326  4.283729  2.430802  24.178798
#
#                                1053      1054      1055      1056     1057  \
# 2015-01-01 00:00:00+01:00  2.580783  1.414335  1.940935  7.542931  1.08628
# 2015-01-01 00:15:00+01:00  2.580783  1.414335  1.940935  7.542931  1.08628
# 2015-01-01 00:30:00+01:00  2.580783  1.414335  1.940935  7.542931  1.08628
# 2015-01-01 00:45:00+01:00  2.580783  1.414335  1.940935  7.542931  1.08628
# 2015-01-01 01:00:00+01:00  2.580783  1.414335  1.940935  7.542931  1.08628
#
#                            ...     16068     16069     16070     16071  \
# 2015-01-01 00:00:00+01:00  ...  4.735791  4.298181  6.941822  3.384061
# 2015-01-01 00:15:00+01:00  ...  4.735791  4.298181  6.941822  3.384061
# 2015-01-01 00:30:00+01:00  ...  4.735791  4.298181  6.941822  3.384061
# 2015-01-01 00:45:00+01:00  ...  4.735791  4.298181  6.941822  3.384061
# 2015-01-01 01:00:00+01:00  ...  4.735791  4.298181  6.941822  3.384061
#
#                               16072      16073     16074      16075    16076  \
# 2015-01-01 00:00:00+01:00  7.304399  17.140225  4.025106  10.430391  3.79203
# 2015-01-01 00:15:00+01:00  7.304399  17.140225  4.025106  10.430391  3.79203
# 2015-01-01 00:30:00+01:00  7.304399  17.140225  4.025106  10.430391  3.79203
# 2015-01-01 00:45:00+01:00  7.304399  17.140225  4.025106  10.430391  3.79203
# 2015-01-01 01:00:00+01:00  7.304399  17.140225  4.025106  10.430391  3.79203
#
#                               16077
# 2015-01-01 00:00:00+01:00  3.417297
# 2015-01-01 00:15:00+01:00  3.417297
# 2015-01-01 00:30:00+01:00  3.417297
# 2015-01-01 00:45:00+01:00  3.417297
# 2015-01-01 01:00:00+01:00  3.417297
#
# [5 rows x 401 columns]

# %%
df_pow_industry.loc[:,['1001', '1002']].head(672).plot(figsize=(12,6))

# %% [markdown]
# ### Function shift_load_profile_generator()
# - calculates normalized shift load profiles for industry
# - S1, S2, S3 meaning shifts from 8:00 to 16:30, 06:00 to 23:00 and continously respectively
# - WT, WT_SA, and WT_SA_SO meaning working on weekdays only (holidays excluded), weekdays + saturdays (holidays excluded), all the time
# - shift has 2 levels, with the lower level being 35% of the higher level

# %%
df_workshift = data.shift_load_profile_generator('BE')

# %%
fig, ax = plt.subplots(figsize=(12,6))

df_workshift.head(672).plot(ax=ax)
ax.legend(loc=4, bbox_to_anchor=(1.2,0))

# %% [markdown]
# ### Function CTS_power_slp_generator()
# -  returns the electric standard load profiles in normalized units ('normalized' means here that the sum over all time steps equals one)
# - takes information from `./data_in/Power Load Profiles/`

# %%
df_power_slp = data.CTS_power_slp_generator('BE')

# %%
df_power_slp[['G0', 'G1']].head(672).plot(figsize=(12,6), ylim = 0)

# %%
df_power_slp
# Out:
#                                   Tag    Stunde  DayOfYear     WT     SA  \
# Date
# 2015-01-01 00:00:00+01:00  2015-01-01  00:00:00          1  False  False
# 2015-01-01 00:15:00+01:00  2015-01-01  00:15:00          1  False  False
# 2015-01-01 00:30:00+01:00  2015-01-01  00:30:00          1  False  False
# 2015-01-01 00:45:00+01:00  2015-01-01  00:45:00          1  False  False
# 2015-01-01 01:00:00+01:00  2015-01-01  01:00:00          1  False  False
# ...                               ...       ...        ...    ...    ...
# 2015-12-31 22:45:00+01:00  2015-12-31  22:45:00        365  False   True
# 2015-12-31 23:00:00+01:00  2015-12-31  23:00:00        365  False   True
# 2015-12-31 23:15:00+01:00  2015-12-31  23:15:00        365  False   True
# 2015-12-31 23:30:00+01:00  2015-12-31  23:30:00        365  False   True
# 2015-12-31 23:45:00+01:00  2015-12-31  23:45:00        365  False   True
#
#                               SO   WIZ    SOZ    UEZ        H0        L0  \
# Date
# 2015-01-01 00:00:00+01:00   True  True  False  False  0.000018  0.000018
# 2015-01-01 00:15:00+01:00   True  True  False  False  0.000022  0.000017
# 2015-01-01 00:30:00+01:00   True  True  False  False  0.000020  0.000016
# 2015-01-01 00:45:00+01:00   True  True  False  False  0.000019  0.000016
# 2015-01-01 01:00:00+01:00   True  True  False  False  0.000017  0.000016
# ...                          ...   ...    ...    ...       ...       ...
# 2015-12-31 22:45:00+01:00  False  True  False  False  0.000030  0.000023
# 2015-12-31 23:00:00+01:00  False  True  False  False  0.000030  0.000022
# 2015-12-31 23:15:00+01:00  False  True  False  False  0.000028  0.000021
# 2015-12-31 23:30:00+01:00  False  True  False  False  0.000027  0.000020
# 2015-12-31 23:45:00+01:00  False  True  False  False  0.000025  0.000019
#
#                                  L1        L2        G0        G1        G2  \
# Date
# 2015-01-01 00:00:00+01:00  0.000017  0.000019  0.000015  0.000007  0.000017
# 2015-01-01 00:15:00+01:00  0.000016  0.000017  0.000016  0.000006  0.000018
# 2015-01-01 00:30:00+01:00  0.000016  0.000017  0.000015  0.000006  0.000017
# 2015-01-01 00:45:00+01:00  0.000015  0.000016  0.000015  0.000006  0.000016
# 2015-01-01 01:00:00+01:00  0.000015  0.000016  0.000014  0.000006  0.000015
# ...                             ...       ...       ...       ...       ...
# 2015-12-31 22:45:00+01:00  0.000020  0.000025  0.000019  0.000007  0.000029
# 2015-12-31 23:00:00+01:00  0.000020  0.000023  0.000018  0.000007  0.000026
# 2015-12-31 23:15:00+01:00  0.000019  0.000022  0.000018  0.000007  0.000023
# 2015-12-31 23:30:00+01:00  0.000018  0.000021  0.000017  0.000007  0.000022
# 2015-12-31 23:45:00+01:00  0.000017  0.000019  0.000017  0.000007  0.000021
#
#                                  G3        G4        G5        G6
# Date
# 2015-01-01 00:00:00+01:00  0.000021  0.000014  0.000009  0.000017
# 2015-01-01 00:15:00+01:00  0.000022  0.000014  0.000010  0.000025
# 2015-01-01 00:30:00+01:00  0.000022  0.000014  0.000010  0.000023
# 2015-01-01 00:45:00+01:00  0.000022  0.000014  0.000009  0.000021
# 2015-01-01 01:00:00+01:00  0.000022  0.000013  0.000010  0.000019
# ...                             ...       ...       ...       ...
# 2015-12-31 22:45:00+01:00  0.000023  0.000015  0.000010  0.000044
# 2015-12-31 23:00:00+01:00  0.000023  0.000015  0.000010  0.000040
# 2015-12-31 23:15:00+01:00  0.000022  0.000015  0.000010  0.000037
# 2015-12-31 23:30:00+01:00  0.000022  0.000015  0.000010  0.000034
# 2015-12-31 23:45:00+01:00  0.000022  0.000015  0.000010  0.000031
#
# [35040 rows x 20 columns]

# %% [markdown]
# ### Function gas_slp_weekday_params()
# - returns the weekday-parameters ("Wochentagsfaktoren") of the gas standard load profiles (SLP) per State and SLP-Type in normalized units for later use in gas SLP

# %%
df_gas_slp = data.gas_slp_weekday_params('BE')

# %%
df_gas_slp[['FW_BA']].head(168).plot(figsize=(12,6), ylim = 0)

# %% [markdown]
# # Auxiliary Functions

# %% [markdown]
# ### Function efficiency_enhancement()
# - Read and return the efficienicy enhancement for power or gas consumption for the current *base year* relative to 2015 per branch. 2015 is the benchmark because specific consumption is based on data from this year.

# %%
df = data.efficiency_enhancement('power')

# %%
df
# Out:
# WZ
# 1     1
# 2     1
# 3     1
# 5     1
# 6     1
#      ..
# 95    1
# 96    1
# 97    1
# 98    1
# 99    1
# Name: Effizienzsteigerungsrate Strom, Length: 88, dtype: int64

# %% [markdown]
# ## Function t_allo()
# - returns the daily allocation temperature for each NUTS-3 district (401 NUTS-3 districts in Germany)
# - t_allo is calculated according to the publication of BDEW on Gas SLPs, p. 22
#
#
# ![grafik.png](attachment:grafik.png)
#
#
# !Line 204 --> Temperatur aus zwei Landkreisen zusammengelegt

# %%
df_t_allo = data.t_allo()
df_t_allo.head()
# Out:
# disaggregator.data: INFO     Dropping old NUTS-v2013 regions.
# ags_lk                         1001      1002      1003      1004      1051  \
# 2015-01-01 00:00:00+01:00  4.846667  3.386667  2.443333  2.976667  3.960000
# 2015-01-02 00:00:00+01:00  5.768980  5.064014  4.500544  4.950204  5.335918
# 2015-01-03 00:00:00+01:00  5.804445  5.265073  4.791282  5.188426  5.744036
# 2015-01-04 00:00:00+01:00  5.126411  4.549156  4.080490  4.507839  5.210513
# 2015-01-05 00:00:00+01:00  4.562905  4.086507  3.618178  3.990390  4.976216
#
# ags_lk                         1053      9774      1054      1055      1056  \
# 2015-01-01 00:00:00+01:00  2.133333 -1.713333  5.140000  2.370000  2.473333
# 2015-01-02 00:00:00+01:00  4.378571 -3.273061  6.098095  4.485442  4.642313
# 2015-01-03 00:00:00+01:00  4.738095 -1.168857  6.325832  4.771270  4.904902
# 2015-01-04 00:00:00+01:00  4.188763 -0.824925  5.840115  4.098049  4.424334
# 2015-01-05 00:00:00+01:00  3.786529 -0.693200  5.565019  3.668190  4.110900
#
# ags_lk                     ...     16068     16069     16070     16071  \
# 2015-01-01 00:00:00+01:00  ...  2.166667  0.000000  0.183333  1.586667
# 2015-01-02 00:00:00+01:00  ...  2.270408 -0.052721 -1.472449  1.651429
# 2015-01-03 00:00:00+01:00  ...  2.575482  0.247927 -1.319332  2.087247
# 2015-01-04 00:00:00+01:00  ...  2.485728  0.269494 -1.262638  1.930961
# 2015-01-05 00:00:00+01:00  ...  2.396788  0.290311 -1.546013  1.873229
#
# ags_lk                        16072     16073     16074     16075     16076  \
# 2015-01-01 00:00:00+01:00  0.163333  1.223333  0.466667  0.960000  0.880000
# 2015-01-02 00:00:00+01:00 -1.357211  1.178027  0.902381  0.744082  0.752653
# 2015-01-03 00:00:00+01:00 -1.349501  1.546128  1.402642  1.080165  1.217804
# 2015-01-04 00:00:00+01:00 -1.297350  1.491930  1.266486  0.980766  1.177418
# 2015-01-05 00:00:00+01:00 -1.623932  1.477079  1.305384  0.962028  1.274715
#
# ags_lk                        16077
# 2015-01-01 00:00:00+01:00  1.003333
# 2015-01-02 00:00:00+01:00  1.369116
# 2015-01-03 00:00:00+01:00  1.949469
# 2015-01-04 00:00:00+01:00  1.799501
# 2015-01-05 00:00:00+01:00  1.840803
#
# [5 rows x 401 columns]

# %% [markdown]
# ## Function h_value()
# - returns a DataFrame with normalized h-values for a given district and gas load profile. normalization is necessary for later use as disaggregation parameter from yearly to daily gas consumption, but can also be turned off
# - h-values depend on the allocation temperature and determine the daily gas consumption

# %%
from disaggregator import config, data, spatial, temporal
df_h_value = data.h_value(slp = 'KO', districts = ['11000'])
df_h_value.head()
# Out:
# disaggregator.data: INFO     Dropping old NUTS-v2013 regions.
# ags_lk                        11000
# 2015-01-01 00:00:00+01:00  0.005148
# 2015-01-02 00:00:00+01:00  0.005072
# 2015-01-03 00:00:00+01:00  0.004716
# 2015-01-04 00:00:00+01:00  0.004881
# 2015-01-05 00:00:00+01:00  0.005046

# %%
df_h_value.plot()
